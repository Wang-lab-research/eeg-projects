# %% [markdown]
# ## Extract eyes open and eyes closed and stop timestamps to crop data for resting state functional connectivity analysis
# ##### Input: *_preprocessed-raw.fif
# #####  Output: *_RestingTStamps.csv
# ######   * = Subject e.g. 018 or C14 etc

# %%
import csv
import os
import sys
import mne
from mne.io import read_raw_fif
# !pip install utils
#import utils
#import something to save in pickle
# Out:
# Requirement already satisfied: utils in /home/sb10flpc002/anaconda3/envs/mne/lib/python3.11/site-packages (1.0.1)

# %%
annotation_keys = {'eyes closed': 1, 'Trigger#1': 1, 'EYES CLOSED': 1, # eyes closed
                      'eyes open': 2, 'eyes opened': 2, 'Trigger#2': 2, 'EYES OPEN': 2, 'eyes openned':2, # eyes open
                      'stop': 9, 'Stop': 9, 'STOP': 9, 'Sop': 9, # stop
                      }
eyesclosed_keys = {'eyes closed': 1, 'Trigger#1': 1, 'EYES CLOSED': 1, # eyes closed
                      'stop': 9, 'Stop': 9, 'STOP': 9, # stop
                      }

eyesopen_keys = {'eyes open': 2, 'eyes opened': 2, 'Trigger#2': 2, 'EYES OPEN': 2, 'eyes openned':2, # eyes open
                      'stop': 9, 'Stop': 9, 'STOP': 9, # stop
                      }

# %%
# Settings
# Read in processed raw data
#data_path = '../../Data/Processed Data/'
#This data path is local to sbflpc002
data_path = '/run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data'
save_path = '../../../Data/Eyes Timestamps/'

if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
file_list = os.listdir(data_path)
# Only select files that end in "raw.fif"
raw_fif_files = [file for file in file_list if file.endswith('raw.fif')]

# %%
file = raw_fif_files[34]
file_path = os.path.join(data_path, file)
raw = read_raw_fif(file_path, preload = False)


events_from_annot, event_dict = mne.events_from_annotations(raw, event_id = annotation_keys)
# Extract timestamps from the events
timestamps_with_id = [(event[0] / raw.info['sfreq'], event[2]) for event in events_from_annot]

# Get name of the file we're looking at
#print(file_path)

# Output timestamps with associated event IDs
print("Timestamps and Associated Event IDs:")
for timestamp, event_id in timestamps_with_id:
    print(f"Timestamp: {timestamp:.3f} seconds, Event ID: {event_id}")
# Out:
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C5._preprocessed-raw.fif...
#     Range : 0 ... 642879 =      0.000 ...  1607.197 secs
# Ready.
# Used Annotations descriptions: ['stop']
# Timestamps and Associated Event IDs:
# Timestamp: 1539.100 seconds, Event ID: 9

# %% [markdown]
# ##### Next, collect the timepoints for the eyes closed, eyes closed stop, eyes open, and eyes open stop

# %%
### Script for a normal timestamp
saved_times = [None, None, None, None]  # Initialize an array to store timestamps

for idx, (timestamp, event_id) in enumerate(timestamps_with_id):
    # Find first instance of event ID 1, then the first instance of event ID 9 afterwards
    # Find first instance of event ID 2, the the first instance of event ID 9 afterwards
    if event_id == 1:
        if saved_times[0] is None:  # Check if the first index is empty
            saved_times[0] = timestamp
    elif event_id == 9 and idx > 0 and timestamps_with_id[idx - 1][1] == 1:
        saved_times[1] = timestamp
    elif event_id == 2:
        if saved_times[2] is None:  # Check if the third index is empty
            saved_times[2] = timestamp
    elif event_id == 9 and idx > 0 and timestamps_with_id[idx - 1][1] == 2:
        saved_times[3] = timestamp

print("Saved Times:", saved_times)
# Out:
# Saved Times: [118.495, 490.095, 529.695, 838.7525]

# %%
# Adjustments to saved times
saved_times[0] = 605.538
saved_times[1] = 660.058
saved_times[2] = 306.735
saved_times[3] = 605.538
print("Saved Times:", saved_times)
# Out:
# Saved Times: [605.538, 660.058, 306.735, 605.538]

# %%
# Function to extract subject ID from the file path
def extract_subject_id(file_path):
    file_name = file_path.split('/')[-1]  # Extract the file name
    subject_id = file_name.split('_')[0]  # Get the part before '_preprocessed-raw.fif'
    return subject_id

# Extract subject ID from the given file paths
subject_id = extract_subject_id(file_path)

# Define the CSV file name
csv_file_name = f"{subject_id}_RestingTStamps.csv"

# Construct the full file path
full_file_path = os.path.join(save_path, csv_file_name)

# Write data to the CSV file
with open(full_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Seconds"])

    for timestamp in saved_times:
        writer.writerow([timestamp])

# %%
file = raw_fif_files[52]
file_path = os.path.join(data_path, file)
raw = read_raw_fif(file_path, preload = False)


events_from_annot, event_dict = mne.events_from_annotations(raw)
# Extract timestamps from the events
timestamps_with_id = [(event[0] / raw.info['sfreq'], event[2]) for event in events_from_annot]

timestamps_event_ids_annotations = []
for idx, event in enumerate(events_from_annot):
    timestamp = event[0] / raw.info['sfreq']  # Timestamp in seconds
    event_id = event[2]  # Event ID
    #use event_dict to get the annotation
    timestamps_event_ids_annotations.append((timestamp, event_id))

# Print the extracted data
for timestamp, event_id, annotation_desc in timestamps_event_ids_annotations:
    print(f"Timestamp: {timestamp:.3f}s, Event ID: {event_id})
# Out:
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/045_preprocessed-raw.fif...
#     Range : 0 ... 617599 =      0.000 ...  1543.997 secs
# Ready.
# Used Annotations descriptions: ['1000001', '1000010', '1100001', '1100010']
# Timestamp: 794.475s, Event ID: 1, Annotation: Unknown
# Timestamp: 795.495s, Event ID: 2, Annotation: Unknown
# Timestamp: 798.315s, Event ID: 1, Annotation: Unknown
# Timestamp: 798.378s, Event ID: 2, Annotation: Unknown
# Timestamp: 807.278s, Event ID: 3, Annotation: Unknown
# Timestamp: 808.312s, Event ID: 4, Annotation: Unknown
# Timestamp: 809.783s, Event ID: 3, Annotation: Unknown
# Timestamp: 809.827s, Event ID: 4, Annotation: Unknown
# Timestamp: 810.342s, Event ID: 3, Annotation: Unknown
# Timestamp: 810.393s, Event ID: 4, Annotation: Unknown
# Timestamp: 816.097s, Event ID: 1, Annotation: Unknown
# Timestamp: 817.133s, Event ID: 2, Annotation: Unknown
# Timestamp: 819.477s, Event ID: 1, Annotation: Unknown
# Timestamp: 819.523s, Event ID: 2, Annotation: Unknown
# Timestamp: 823.880s, Event ID: 3, Annotation: Unknown
# Timestamp: 823.923s, Event ID: 4, Annotation: Unknown
# Timestamp: 826.933s, Event ID: 3, Annotation: Unknown
# Timestamp: 827.915s, Event ID: 4, Annotation: Unknown
# Timestamp: 837.205s, Event ID: 3, Annotation: Unknown
# Timestamp: 838.117s, Event ID: 4, Annotation: Unknown
# Timestamp: 847.745s, Event ID: 1, Annotation: Unknown
# Timestamp: 848.695s, Event ID: 2, Annotation: Unknown
# Timestamp: 849.712s, Event ID: 1, Annotation: Unknown
# Timestamp: 849.760s, Event ID: 2, Annotation: Unknown
# Timestamp: 849.770s, Event ID: 1, Annotation: Unknown
# Timestamp: 849.815s, Event ID: 2, Annotation: Unknown
# Timestamp: 850.577s, Event ID: 1, Annotation: Unknown
# Timestamp: 850.622s, Event ID: 2, Annotation: Unknown
# Timestamp: 856.222s, Event ID: 3, Annotation: Unknown
# Timestamp: 857.303s, Event ID: 4, Annotation: Unknown
# Timestamp: 858.465s, Event ID: 3, Annotation: Unknown
# Timestamp: 858.510s, Event ID: 4, Annotation: Unknown
# Timestamp: 859.065s, Event ID: 3, Annotation: Unknown
# Timestamp: 859.110s, Event ID: 4, Annotation: Unknown
# Timestamp: 867.288s, Event ID: 3, Annotation: Unknown
# Timestamp: 868.265s, Event ID: 4, Annotation: Unknown
# Timestamp: 869.268s, Event ID: 3, Annotation: Unknown
# Timestamp: 869.332s, Event ID: 4, Annotation: Unknown
# Timestamp: 873.942s, Event ID: 1, Annotation: Unknown
# Timestamp: 874.005s, Event ID: 2, Annotation: Unknown
# Timestamp: 876.500s, Event ID: 1, Annotation: Unknown
# Timestamp: 877.518s, Event ID: 2, Annotation: Unknown
# Timestamp: 878.725s, Event ID: 1, Annotation: Unknown
# Timestamp: 878.770s, Event ID: 2, Annotation: Unknown
# Timestamp: 887.660s, Event ID: 1, Annotation: Unknown
# Timestamp: 888.665s, Event ID: 2, Annotation: Unknown
# Timestamp: 889.790s, Event ID: 1, Annotation: Unknown
# Timestamp: 889.900s, Event ID: 2, Annotation: Unknown
# Timestamp: 889.960s, Event ID: 1, Annotation: Unknown
# Timestamp: 890.005s, Event ID: 2, Annotation: Unknown
# Timestamp: 890.670s, Event ID: 1, Annotation: Unknown
# Timestamp: 890.715s, Event ID: 2, Annotation: Unknown
# Timestamp: 891.180s, Event ID: 1, Annotation: Unknown
# Timestamp: 891.183s, Event ID: 2, Annotation: Unknown
# Timestamp: 892.335s, Event ID: 1, Annotation: Unknown
# Timestamp: 892.380s, Event ID: 2, Annotation: Unknown
# Timestamp: 902.447s, Event ID: 3, Annotation: Unknown
# Timestamp: 903.612s, Event ID: 4, Annotation: Unknown
# Timestamp: 904.645s, Event ID: 3, Annotation: Unknown
# Timestamp: 905.890s, Event ID: 4, Annotation: Unknown
# Timestamp: 906.650s, Event ID: 3, Annotation: Unknown
# Timestamp: 906.692s, Event ID: 4, Annotation: Unknown
# Timestamp: 909.492s, Event ID: 3, Annotation: Unknown
# Timestamp: 909.610s, Event ID: 4, Annotation: Unknown
# Timestamp: 909.650s, Event ID: 3, Annotation: Unknown
# Timestamp: 909.655s, Event ID: 1, Annotation: Unknown
# Timestamp: 909.715s, Event ID: 2, Annotation: Unknown
# Timestamp: 909.740s, Event ID: 4, Annotation: Unknown
# Timestamp: 912.872s, Event ID: 3, Annotation: Unknown
# Timestamp: 913.987s, Event ID: 4, Annotation: Unknown
# Timestamp: 915.165s, Event ID: 3, Annotation: Unknown
# Timestamp: 915.275s, Event ID: 4, Annotation: Unknown
# Timestamp: 916.000s, Event ID: 3, Annotation: Unknown
# Timestamp: 916.053s, Event ID: 4, Annotation: Unknown
# Timestamp: 922.170s, Event ID: 1, Annotation: Unknown
# Timestamp: 923.247s, Event ID: 2, Annotation: Unknown
# Timestamp: 924.485s, Event ID: 1, Annotation: Unknown
# Timestamp: 924.622s, Event ID: 2, Annotation: Unknown
# Timestamp: 924.692s, Event ID: 1, Annotation: Unknown
# Timestamp: 924.750s, Event ID: 2, Annotation: Unknown
# Timestamp: 925.697s, Event ID: 1, Annotation: Unknown
# Timestamp: 925.742s, Event ID: 2, Annotation: Unknown
# Timestamp: 929.850s, Event ID: 1, Annotation: Unknown
# Timestamp: 929.895s, Event ID: 2, Annotation: Unknown
# Timestamp: 932.933s, Event ID: 1, Annotation: Unknown
# Timestamp: 934.010s, Event ID: 2, Annotation: Unknown
# Timestamp: 935.558s, Event ID: 1, Annotation: Unknown
# Timestamp: 935.633s, Event ID: 2, Annotation: Unknown
# Timestamp: 936.425s, Event ID: 1, Annotation: Unknown
# Timestamp: 936.470s, Event ID: 2, Annotation: Unknown
# Timestamp: 955.707s, Event ID: 3, Annotation: Unknown
# Timestamp: 956.885s, Event ID: 4, Annotation: Unknown
# Timestamp: 958.155s, Event ID: 3, Annotation: Unknown
# Timestamp: 958.222s, Event ID: 4, Annotation: Unknown
# Timestamp: 959.270s, Event ID: 3, Annotation: Unknown
# Timestamp: 959.315s, Event ID: 4, Annotation: Unknown
# Timestamp: 964.065s, Event ID: 1, Annotation: Unknown
# Timestamp: 964.112s, Event ID: 2, Annotation: Unknown
# Timestamp: 967.560s, Event ID: 1, Annotation: Unknown
# Timestamp: 968.685s, Event ID: 2, Annotation: Unknown
# Timestamp: 970.010s, Event ID: 1, Annotation: Unknown
# Timestamp: 970.212s, Event ID: 2, Annotation: Unknown
# Timestamp: 970.255s, Event ID: 1, Annotation: Unknown
# Timestamp: 970.312s, Event ID: 2, Annotation: Unknown
# Timestamp: 979.015s, Event ID: 1, Annotation: Unknown
# Timestamp: 980.100s, Event ID: 2, Annotation: Unknown
# Timestamp: 981.515s, Event ID: 1, Annotation: Unknown
# Timestamp: 981.587s, Event ID: 2, Annotation: Unknown
# Timestamp: 982.457s, Event ID: 1, Annotation: Unknown
# Timestamp: 982.503s, Event ID: 2, Annotation: Unknown
# Timestamp: 983.097s, Event ID: 1, Annotation: Unknown
# Timestamp: 983.143s, Event ID: 2, Annotation: Unknown
# Timestamp: 990.210s, Event ID: 3, Annotation: Unknown
# Timestamp: 991.325s, Event ID: 4, Annotation: Unknown
# Timestamp: 992.653s, Event ID: 3, Annotation: Unknown
# Timestamp: 992.695s, Event ID: 4, Annotation: Unknown
# Timestamp: 993.258s, Event ID: 3, Annotation: Unknown
# Timestamp: 993.303s, Event ID: 4, Annotation: Unknown
# Timestamp: 1002.232s, Event ID: 1, Annotation: Unknown
# Timestamp: 1003.275s, Event ID: 2, Annotation: Unknown
# Timestamp: 1004.775s, Event ID: 1, Annotation: Unknown
# Timestamp: 1004.832s, Event ID: 2, Annotation: Unknown
# Timestamp: 1004.855s, Event ID: 1, Annotation: Unknown
# Timestamp: 1004.855s, Event ID: 2, Annotation: Unknown
# Timestamp: 1005.240s, Event ID: 1, Annotation: Unknown
# Timestamp: 1005.300s, Event ID: 2, Annotation: Unknown
# Timestamp: 1005.658s, Event ID: 1, Annotation: Unknown
# Timestamp: 1005.702s, Event ID: 2, Annotation: Unknown
# Timestamp: 1017.650s, Event ID: 3, Annotation: Unknown
# Timestamp: 1018.760s, Event ID: 4, Annotation: Unknown
# Timestamp: 1020.170s, Event ID: 3, Annotation: Unknown
# Timestamp: 1020.215s, Event ID: 4, Annotation: Unknown
# Timestamp: 1020.913s, Event ID: 3, Annotation: Unknown
# Timestamp: 1020.965s, Event ID: 4, Annotation: Unknown
# Timestamp: 1027.497s, Event ID: 1, Annotation: Unknown
# Timestamp: 1032.705s, Event ID: 2, Annotation: Unknown
# Timestamp: 1039.122s, Event ID: 3, Annotation: Unknown
# Timestamp: 1040.130s, Event ID: 4, Annotation: Unknown
# Timestamp: 1046.223s, Event ID: 1, Annotation: Unknown
# Timestamp: 1046.267s, Event ID: 2, Annotation: Unknown
# Timestamp: 1048.415s, Event ID: 1, Annotation: Unknown
# Timestamp: 1049.440s, Event ID: 2, Annotation: Unknown
# Timestamp: 1050.640s, Event ID: 1, Annotation: Unknown
# Timestamp: 1050.685s, Event ID: 2, Annotation: Unknown
# Timestamp: 1063.365s, Event ID: 3, Annotation: Unknown
# Timestamp: 1064.402s, Event ID: 4, Annotation: Unknown
# Timestamp: 1065.375s, Event ID: 3, Annotation: Unknown
# Timestamp: 1065.418s, Event ID: 4, Annotation: Unknown
# Timestamp: 1065.818s, Event ID: 3, Annotation: Unknown
# Timestamp: 1065.862s, Event ID: 4, Annotation: Unknown
# Timestamp: 1072.932s, Event ID: 1, Annotation: Unknown
# Timestamp: 1073.868s, Event ID: 2, Annotation: Unknown
# Timestamp: 1074.912s, Event ID: 1, Annotation: Unknown
# Timestamp: 1075.010s, Event ID: 2, Annotation: Unknown
# Timestamp: 1083.350s, Event ID: 3, Annotation: Unknown
# Timestamp: 1084.303s, Event ID: 4, Annotation: Unknown
# Timestamp: 1085.405s, Event ID: 3, Annotation: Unknown
# Timestamp: 1085.450s, Event ID: 4, Annotation: Unknown
# Timestamp: 1099.078s, Event ID: 3, Annotation: Unknown
# Timestamp: 1100.108s, Event ID: 4, Annotation: Unknown
# Timestamp: 1101.020s, Event ID: 3, Annotation: Unknown
# Timestamp: 1101.075s, Event ID: 4, Annotation: Unknown
# Timestamp: 1101.185s, Event ID: 3, Annotation: Unknown
# Timestamp: 1101.240s, Event ID: 4, Annotation: Unknown
# Timestamp: 1102.168s, Event ID: 3, Annotation: Unknown
# Timestamp: 1102.220s, Event ID: 4, Annotation: Unknown
# Timestamp: 1102.922s, Event ID: 3, Annotation: Unknown
# Timestamp: 1102.997s, Event ID: 4, Annotation: Unknown
# Timestamp: 1110.862s, Event ID: 1, Annotation: Unknown
# Timestamp: 1111.993s, Event ID: 2, Annotation: Unknown
# Timestamp: 1118.535s, Event ID: 3, Annotation: Unknown
# Timestamp: 1118.580s, Event ID: 4, Annotation: Unknown
# Timestamp: 1121.690s, Event ID: 3, Annotation: Unknown
# Timestamp: 1122.840s, Event ID: 4, Annotation: Unknown
# Timestamp: 1123.688s, Event ID: 3, Annotation: Unknown
# Timestamp: 1123.858s, Event ID: 4, Annotation: Unknown
# Timestamp: 1140.040s, Event ID: 1, Annotation: Unknown
# Timestamp: 1141.075s, Event ID: 2, Annotation: Unknown
# Timestamp: 1142.255s, Event ID: 1, Annotation: Unknown
# Timestamp: 1142.320s, Event ID: 2, Annotation: Unknown
# Timestamp: 1150.915s, Event ID: 1, Annotation: Unknown
# Timestamp: 1151.973s, Event ID: 2, Annotation: Unknown
# Timestamp: 1152.905s, Event ID: 1, Annotation: Unknown
# Timestamp: 1153.088s, Event ID: 2, Annotation: Unknown
# Timestamp: 1161.895s, Event ID: 1, Annotation: Unknown
# Timestamp: 1163.410s, Event ID: 2, Annotation: Unknown
# Timestamp: 1163.645s, Event ID: 1, Annotation: Unknown
# Timestamp: 1163.690s, Event ID: 2, Annotation: Unknown
# Timestamp: 1164.480s, Event ID: 1, Annotation: Unknown
# Timestamp: 1164.570s, Event ID: 2, Annotation: Unknown
# Timestamp: 1165.940s, Event ID: 1, Annotation: Unknown
# Timestamp: 1165.995s, Event ID: 2, Annotation: Unknown
# Timestamp: 1177.755s, Event ID: 1, Annotation: Unknown
# Timestamp: 1178.858s, Event ID: 2, Annotation: Unknown
# Timestamp: 1179.100s, Event ID: 1, Annotation: Unknown
# Timestamp: 1179.165s, Event ID: 2, Annotation: Unknown
# Timestamp: 1179.213s, Event ID: 1, Annotation: Unknown
# Timestamp: 1179.410s, Event ID: 2, Annotation: Unknown
# Timestamp: 1179.428s, Event ID: 1, Annotation: Unknown
# Timestamp: 1179.585s, Event ID: 2, Annotation: Unknown
# Timestamp: 1179.618s, Event ID: 1, Annotation: Unknown
# Timestamp: 1179.822s, Event ID: 2, Annotation: Unknown
# Timestamp: 1179.840s, Event ID: 1, Annotation: Unknown
# Timestamp: 1179.918s, Event ID: 2, Annotation: Unknown
# Timestamp: 1180.003s, Event ID: 1, Annotation: Unknown
# Timestamp: 1180.050s, Event ID: 2, Annotation: Unknown
# Timestamp: 1180.235s, Event ID: 1, Annotation: Unknown
# Timestamp: 1180.295s, Event ID: 2, Annotation: Unknown
# Timestamp: 1180.447s, Event ID: 1, Annotation: Unknown
# Timestamp: 1180.530s, Event ID: 2, Annotation: Unknown
# Timestamp: 1180.535s, Event ID: 1, Annotation: Unknown
# Timestamp: 1180.582s, Event ID: 2, Annotation: Unknown
# Timestamp: 1180.625s, Event ID: 1, Annotation: Unknown
# Timestamp: 1180.670s, Event ID: 2, Annotation: Unknown
# Timestamp: 1181.425s, Event ID: 1, Annotation: Unknown
# Timestamp: 1181.503s, Event ID: 2, Annotation: Unknown
# Timestamp: 1185.345s, Event ID: 1, Annotation: Unknown
# Timestamp: 1185.390s, Event ID: 2, Annotation: Unknown
# Timestamp: 1191.405s, Event ID: 3, Annotation: Unknown
# Timestamp: 1192.453s, Event ID: 4, Annotation: Unknown
# Timestamp: 1194.680s, Event ID: 3, Annotation: Unknown
# Timestamp: 1194.735s, Event ID: 4, Annotation: Unknown
# Timestamp: 1204.142s, Event ID: 3, Annotation: Unknown
# Timestamp: 1205.165s, Event ID: 4, Annotation: Unknown
# Timestamp: 1213.408s, Event ID: 1, Annotation: Unknown
# Timestamp: 1213.460s, Event ID: 2, Annotation: Unknown
# Timestamp: 1213.473s, Event ID: 1, Annotation: Unknown
# Timestamp: 1213.580s, Event ID: 2, Annotation: Unknown
# Timestamp: 1213.912s, Event ID: 1, Annotation: Unknown
# Timestamp: 1213.957s, Event ID: 2, Annotation: Unknown
# Timestamp: 1214.210s, Event ID: 1, Annotation: Unknown
# Timestamp: 1214.265s, Event ID: 2, Annotation: Unknown
# Timestamp: 1214.305s, Event ID: 1, Annotation: Unknown
# Timestamp: 1214.350s, Event ID: 2, Annotation: Unknown
# Timestamp: 1214.960s, Event ID: 1, Annotation: Unknown
# Timestamp: 1215.040s, Event ID: 2, Annotation: Unknown
# Timestamp: 1215.100s, Event ID: 1, Annotation: Unknown
# Timestamp: 1215.148s, Event ID: 2, Annotation: Unknown
# Timestamp: 1217.815s, Event ID: 1, Annotation: Unknown
# Timestamp: 1219.047s, Event ID: 2, Annotation: Unknown
# Timestamp: 1219.697s, Event ID: 1, Annotation: Unknown
# Timestamp: 1219.743s, Event ID: 2, Annotation: Unknown
# Timestamp: 1221.868s, Event ID: 1, Annotation: Unknown
# Timestamp: 1221.912s, Event ID: 2, Annotation: Unknown
# Timestamp: 1231.290s, Event ID: 3, Annotation: Unknown
# Timestamp: 1232.297s, Event ID: 4, Annotation: Unknown
# Timestamp: 1233.713s, Event ID: 3, Annotation: Unknown
# Timestamp: 1233.790s, Event ID: 4, Annotation: Unknown
# Timestamp: 1240.723s, Event ID: 1, Annotation: Unknown
# Timestamp: 1240.770s, Event ID: 2, Annotation: Unknown
# Timestamp: 1241.075s, Event ID: 1, Annotation: Unknown
# Timestamp: 1241.120s, Event ID: 2, Annotation: Unknown
# Timestamp: 1241.130s, Event ID: 1, Annotation: Unknown
# Timestamp: 1241.215s, Event ID: 2, Annotation: Unknown
# Timestamp: 1246.565s, Event ID: 1, Annotation: Unknown
# Timestamp: 1247.755s, Event ID: 2, Annotation: Unknown
# Timestamp: 1249.370s, Event ID: 1, Annotation: Unknown
# Timestamp: 1249.370s, Event ID: 2, Annotation: Unknown
# Timestamp: 1258.503s, Event ID: 3, Annotation: Unknown
# Timestamp: 1259.600s, Event ID: 4, Annotation: Unknown
# Timestamp: 1260.665s, Event ID: 3, Annotation: Unknown
# Timestamp: 1260.795s, Event ID: 4, Annotation: Unknown
# Timestamp: 1260.925s, Event ID: 3, Annotation: Unknown
# Timestamp: 1260.980s, Event ID: 4, Annotation: Unknown
# Timestamp: 1261.615s, Event ID: 3, Annotation: Unknown
# Timestamp: 1261.680s, Event ID: 4, Annotation: Unknown
# Timestamp: 1266.175s, Event ID: 1, Annotation: Unknown
# Timestamp: 1266.223s, Event ID: 2, Annotation: Unknown
# Timestamp: 1270.168s, Event ID: 1, Annotation: Unknown
# Timestamp: 1271.220s, Event ID: 2, Annotation: Unknown
# Timestamp: 1273.450s, Event ID: 1, Annotation: Unknown
# Timestamp: 1273.497s, Event ID: 2, Annotation: Unknown
# Timestamp: 1281.305s, Event ID: 3, Annotation: Unknown
# Timestamp: 1282.400s, Event ID: 4, Annotation: Unknown
# Timestamp: 1283.670s, Event ID: 3, Annotation: Unknown
# Timestamp: 1283.765s, Event ID: 4, Annotation: Unknown
# Timestamp: 1284.275s, Event ID: 3, Annotation: Unknown
# Timestamp: 1284.335s, Event ID: 4, Annotation: Unknown
# Timestamp: 1288.910s, Event ID: 3, Annotation: Unknown
# Timestamp: 1292.470s, Event ID: 4, Annotation: Unknown
# Timestamp: 1296.787s, Event ID: 1, Annotation: Unknown
# Timestamp: 1296.835s, Event ID: 2, Annotation: Unknown
# Timestamp: 1299.010s, Event ID: 1, Annotation: Unknown
# Timestamp: 1300.178s, Event ID: 2, Annotation: Unknown
# Timestamp: 1300.265s, Event ID: 1, Annotation: Unknown
# Timestamp: 1300.310s, Event ID: 2, Annotation: Unknown
# Timestamp: 1300.340s, Event ID: 1, Annotation: Unknown
# Timestamp: 1300.395s, Event ID: 2, Annotation: Unknown
# Timestamp: 1300.400s, Event ID: 1, Annotation: Unknown
# Timestamp: 1300.487s, Event ID: 2, Annotation: Unknown
# Timestamp: 1300.497s, Event ID: 1, Annotation: Unknown
# Timestamp: 1300.665s, Event ID: 2, Annotation: Unknown
# Timestamp: 1300.735s, Event ID: 1, Annotation: Unknown
# Timestamp: 1300.797s, Event ID: 2, Annotation: Unknown
# Timestamp: 1310.550s, Event ID: 1, Annotation: Unknown
# Timestamp: 1311.595s, Event ID: 2, Annotation: Unknown
# Timestamp: 1312.795s, Event ID: 1, Annotation: Unknown
# Timestamp: 1312.858s, Event ID: 2, Annotation: Unknown
# Timestamp: 1314.570s, Event ID: 1, Annotation: Unknown
# Timestamp: 1314.615s, Event ID: 2, Annotation: Unknown
# Timestamp: 1321.717s, Event ID: 3, Annotation: Unknown
# Timestamp: 1322.625s, Event ID: 4, Annotation: Unknown
# Timestamp: 1323.648s, Event ID: 3, Annotation: Unknown
# Timestamp: 1323.725s, Event ID: 4, Annotation: Unknown
# Timestamp: 1323.757s, Event ID: 3, Annotation: Unknown
# Timestamp: 1323.800s, Event ID: 4, Annotation: Unknown
# Timestamp: 1324.620s, Event ID: 3, Annotation: Unknown
# Timestamp: 1324.662s, Event ID: 4, Annotation: Unknown
# Timestamp: 1335.645s, Event ID: 3, Annotation: Unknown
# Timestamp: 1336.543s, Event ID: 4, Annotation: Unknown
# Timestamp: 1337.450s, Event ID: 3, Annotation: Unknown
# Timestamp: 1337.505s, Event ID: 4, Annotation: Unknown
# Timestamp: 1338.835s, Event ID: 3, Annotation: Unknown
# Timestamp: 1338.890s, Event ID: 4, Annotation: Unknown
# Timestamp: 1346.473s, Event ID: 1, Annotation: Unknown
# Timestamp: 1347.398s, Event ID: 2, Annotation: Unknown
# Timestamp: 1348.237s, Event ID: 1, Annotation: Unknown
# Timestamp: 1348.372s, Event ID: 2, Annotation: Unknown
# Timestamp: 1356.928s, Event ID: 3, Annotation: Unknown
# Timestamp: 1357.975s, Event ID: 4, Annotation: Unknown
# Timestamp: 1358.995s, Event ID: 3, Annotation: Unknown
# Timestamp: 1359.115s, Event ID: 4, Annotation: Unknown
# Timestamp: 1359.370s, Event ID: 3, Annotation: Unknown
# Timestamp: 1359.415s, Event ID: 4, Annotation: Unknown
# Timestamp: 1360.892s, Event ID: 3, Annotation: Unknown
# Timestamp: 1360.935s, Event ID: 4, Annotation: Unknown
# Timestamp: 1367.755s, Event ID: 3, Annotation: Unknown
# Timestamp: 1368.745s, Event ID: 4, Annotation: Unknown
# Timestamp: 1369.763s, Event ID: 3, Annotation: Unknown
# Timestamp: 1369.848s, Event ID: 4, Annotation: Unknown
# Timestamp: 1369.860s, Event ID: 3, Annotation: Unknown
# Timestamp: 1369.915s, Event ID: 4, Annotation: Unknown
# Timestamp: 1375.820s, Event ID: 1, Annotation: Unknown
# Timestamp: 1375.930s, Event ID: 2, Annotation: Unknown
# Timestamp: 1379.513s, Event ID: 1, Annotation: Unknown
# Timestamp: 1380.625s, Event ID: 2, Annotation: Unknown
# Timestamp: 1382.685s, Event ID: 1, Annotation: Unknown
# Timestamp: 1382.740s, Event ID: 2, Annotation: Unknown
# Timestamp: 1387.848s, Event ID: 3, Annotation: Unknown
# Timestamp: 1387.905s, Event ID: 4, Annotation: Unknown
# Timestamp: 1390.682s, Event ID: 3, Annotation: Unknown
# Timestamp: 1391.713s, Event ID: 4, Annotation: Unknown
# Timestamp: 1393.805s, Event ID: 3, Annotation: Unknown
# Timestamp: 1393.850s, Event ID: 4, Annotation: Unknown
# Timestamp: 1401.953s, Event ID: 1, Annotation: Unknown
# Timestamp: 1403.015s, Event ID: 2, Annotation: Unknown
# Timestamp: 1405.250s, Event ID: 1, Annotation: Unknown
# Timestamp: 1405.295s, Event ID: 2, Annotation: Unknown
# Timestamp: 1411.840s, Event ID: 3, Annotation: Unknown
# Timestamp: 1411.918s, Event ID: 4, Annotation: Unknown
# Timestamp: 1415.725s, Event ID: 3, Annotation: Unknown
# Timestamp: 1416.940s, Event ID: 4, Annotation: Unknown
# Timestamp: 1418.412s, Event ID: 3, Annotation: Unknown
# Timestamp: 1418.497s, Event ID: 4, Annotation: Unknown
# Timestamp: 1423.940s, Event ID: 1, Annotation: Unknown
# Timestamp: 1423.985s, Event ID: 2, Annotation: Unknown
# Timestamp: 1428.168s, Event ID: 1, Annotation: Unknown
# Timestamp: 1429.305s, Event ID: 2, Annotation: Unknown
# Timestamp: 1430.592s, Event ID: 1, Annotation: Unknown
# Timestamp: 1430.860s, Event ID: 2, Annotation: Unknown
# Timestamp: 1440.365s, Event ID: 1, Annotation: Unknown
# Timestamp: 1441.588s, Event ID: 2, Annotation: Unknown
# Timestamp: 1447.905s, Event ID: 3, Annotation: Unknown
# Timestamp: 1447.950s, Event ID: 4, Annotation: Unknown
# Timestamp: 1451.195s, Event ID: 3, Annotation: Unknown
# Timestamp: 1452.430s, Event ID: 4, Annotation: Unknown
# Timestamp: 1453.830s, Event ID: 3, Annotation: Unknown
# Timestamp: 1453.875s, Event ID: 4, Annotation: Unknown
# Timestamp: 1455.445s, Event ID: 3, Annotation: Unknown
# Timestamp: 1455.490s, Event ID: 4, Annotation: Unknown
# Timestamp: 1461.953s, Event ID: 1, Annotation: Unknown
# Timestamp: 1463.102s, Event ID: 2, Annotation: Unknown
# Timestamp: 1464.247s, Event ID: 1, Annotation: Unknown
# Timestamp: 1464.425s, Event ID: 2, Annotation: Unknown
# Timestamp: 1464.547s, Event ID: 1, Annotation: Unknown
# Timestamp: 1464.630s, Event ID: 2, Annotation: Unknown
# Timestamp: 1465.598s, Event ID: 1, Annotation: Unknown
# Timestamp: 1465.642s, Event ID: 2, Annotation: Unknown
# Timestamp: 1479.045s, Event ID: 1, Annotation: Unknown
# Timestamp: 1480.100s, Event ID: 2, Annotation: Unknown
# Timestamp: 1481.600s, Event ID: 1, Annotation: Unknown
# Timestamp: 1481.648s, Event ID: 2, Annotation: Unknown
# Timestamp: 1482.642s, Event ID: 1, Annotation: Unknown
# Timestamp: 1482.688s, Event ID: 2, Annotation: Unknown
# Timestamp: 1487.828s, Event ID: 3, Annotation: Unknown
# Timestamp: 1487.828s, Event ID: 4, Annotation: Unknown
# Timestamp: 1491.328s, Event ID: 3, Annotation: Unknown
# Timestamp: 1492.400s, Event ID: 4, Annotation: Unknown
# Timestamp: 1505.760s, Event ID: 1, Annotation: Unknown
# Timestamp: 1506.882s, Event ID: 2, Annotation: Unknown
# Timestamp: 1518.270s, Event ID: 3, Annotation: Unknown
# Timestamp: 1519.318s, Event ID: 4, Annotation: Unknown
# Timestamp: 1520.793s, Event ID: 3, Annotation: Unknown
# Timestamp: 1520.838s, Event ID: 4, Annotation: Unknown
# Timestamp: 1536.275s, Event ID: 3, Annotation: Unknown
# Timestamp: 1537.555s, Event ID: 4, Annotation: Unknown
# Timestamp: 1539.000s, Event ID: 3, Annotation: Unknown
# Timestamp: 1539.043s, Event ID: 4, Annotation: Unknown
# Timestamp: 1539.870s, Event ID: 3, Annotation: Unknown
# Timestamp: 1539.915s, Event ID: 4, Annotation: Unknown

# %%
event_dict
# Out:
# {'1000001': 1, '1000010': 2, '1100001': 3, '1100010': 4}

# %%
raw.plot()
# Out:
# Channels marked as bad:
# none
# Attempting to create new mne-python configuration file:
# /home/sb10flpc002/.mne/mne-python.json
# Channels marked as bad:
# none
# Channels marked as bad:
# ['F8']

# %%
file = raw_fif_files[3]
file_path = os.path.join(data_path, file)
raw = read_raw_fif(file_path, preload = False)


events_from_annot, event_dict = mne.events_from_annotations(raw, event_id = annotation_keys)
# Extract timestamps from the events
timestamps_with_id = [(event[0] / raw.info['sfreq'], event[2]) for event in events_from_annot]

# Output timestamps with associated event IDs
print("Timestamps and Associated Event IDs:")
for timestamp, event_id in timestamps_with_id:
    print(f"Timestamp: {timestamp:.3f} seconds, Event ID: {event_id}")
# Out:
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C1._preprocessed-raw.fif...
#     Range : 0 ... 942239 =      0.000 ...  2355.597 secs
# Ready.
# Used Annotations descriptions: ['eyes closed', 'eyes openned']
# Timestamps and Associated Event IDs:
# Timestamp: 22.552 seconds, Event ID: 1
# Timestamp: 323.452 seconds, Event ID: 2
# Timestamp: 482.840 seconds, Event ID: 2
