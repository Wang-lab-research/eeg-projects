# %% [markdown]
# ## Extract eyes open and eyes closed and stop timestamps to crop data for resting state functional connectivity analysis
# ##### Input: *_preprocessed-raw.fif
# #####  Output: *_RestingTStamps.csv
# ######   Where * = Subject e.g. 018 or C14 etc

# %%
import os
import sys
import mne
from mne.io import read_raw_fif
# !pip install utils
#import utils
#import something to save in pickle
# Out:
# Requirement already satisfied: utils in /home/sb10flpc002/anaconda3/envs/mne/lib/python3.11/site-packages (1.0.1)

# %%
annotation_keys = {'eyes closed': 1, 'Trigger#1': 1, 'EYES CLOSED': 1, # eyes closed
                      'eyes open': 2, 'eyes opened': 2, 'Trigger#2': 2, 'EYES OPEN': 2, 'eyes openned':2, # eyes open
                      'stop': 9, 'Stop': 9, 'STOP': 9, # stop
                      }

# %%
# Settings
# Read in processed raw data
#data_path = '../../Data/Processed Data/'
#This data path is local to sbflpc002
data_path = '/run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data'
save_path = '../../../Data/Eyes Timestamps/'

if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
# Import the data
file_list = os.listdir(data_path)
# Only select files that end in "raw.fif"
raw_fif_files = [file for file in file_list if file.endswith('raw.fif')]

# Loop through the filtered files and load them
for file_name in raw_fif_files:
    file_path = os.path.join(data_path, file_name)
    raw = read_raw_fif(file_path, preload = False)
    #Pull the marker times here.
    print(f"Loaded file: {file_name}")
# Out:
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/039_preprocessed-raw.fif...
#     Range : 0 ... 602879 =      0.000 ...  1507.197 secs
# Ready.
# Loaded file: 039_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C15_preprocessed-raw.fif...
#     Range : 0 ... 717599 =      0.000 ...  1793.997 secs
# Ready.
# Loaded file: C15_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C10_preprocessed-raw.fif...
#     Range : 0 ... 801599 =      0.000 ...  2003.997 secs
# Ready.
# Loaded file: C10_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C1._preprocessed-raw.fif...
#     Range : 0 ... 942239 =      0.000 ...  2355.597 secs
# Ready.
# Loaded file: C1._preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/048_preprocessed-raw.fif...
#     Range : 0 ... 846719 =      0.000 ...  2116.798 secs
# Ready.
# Loaded file: 048_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/036_preprocessed-raw.fif...
#     Range : 0 ... 693599 =      0.000 ...  1733.997 secs
# Ready.
# Loaded file: 036_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/031_preprocessed-raw.fif...
#     Range : 0 ... 940639 =      0.000 ...  2351.597 secs
# Ready.
# Loaded file: 031_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/014_preprocessed-raw.fif...
#     Range : 0 ... 861599 =      0.000 ...  2153.997 secs
# Ready.
# Loaded file: 014_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C24_preprocessed-raw.fif...
#     Range : 0 ... 728799 =      0.000 ...  1821.997 secs
# Ready.
# Loaded file: C24_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C9._preprocessed-raw.fif...
#     Range : 0 ... 809599 =      0.000 ...  2023.997 secs
# Ready.
# Loaded file: C9._preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/015_preprocessed-raw.fif...
#     Range : 0 ... 739999 =      0.000 ...  1849.997 secs
# Ready.
# Loaded file: 015_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/033_preprocessed-raw.fif...
#     Range : 0 ... 728639 =      0.000 ...  1821.598 secs
# Ready.
# Loaded file: 033_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/009_preprocessed-raw.fif...
#     Range : 0 ... 700799 =      0.000 ...  1751.997 secs
# Ready.
# Loaded file: 009_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C20_preprocessed-raw.fif...
#     Range : 0 ... 526879 =      0.000 ...  1317.197 secs
# Ready.
# Loaded file: C20_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C12_preprocessed-raw.fif...
#     Range : 0 ... 696479 =      0.000 ...  1741.197 secs
# Ready.
# Loaded file: C12_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C21_preprocessed-raw.fif...
#     Range : 0 ... 627199 =      0.000 ...  1567.997 secs
# Ready.
# Loaded file: C21_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/023_preprocessed-raw.fif...
#     Range : 0 ... 783679 =      0.000 ...  1959.197 secs
# Ready.
# Loaded file: 023_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/013_preprocessed-raw.fif...
#     Range : 0 ... 867199 =      0.000 ...  2167.997 secs
# Ready.
# Loaded file: 013_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/056_preprocessed-raw.fif...
#     Range : 0 ... 769919 =      0.000 ...  1924.797 secs
# Ready.
# Loaded file: 056_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/046_preprocessed-raw.fif...
#     Range : 0 ... 710879 =      0.000 ...  1777.197 secs
# Ready.
# Loaded file: 046_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/050_preprocessed-raw.fif...
#     Range : 0 ... 903519 =      0.000 ...  2258.798 secs
# Ready.
# Loaded file: 050_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/022_preprocessed-raw.fif...
#     Range : 0 ... 810879 =      0.000 ...  2027.197 secs
# Ready.
# Loaded file: 022_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/049_preprocessed-raw.fif...
#     Range : 0 ... 824159 =      0.000 ...  2060.398 secs
# Ready.
# Loaded file: 049_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C8._preprocessed-raw.fif...
#     Range : 0 ... 739359 =      0.000 ...  1848.398 secs
# Ready.
# Loaded file: C8._preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C14_preprocessed-raw.fif...
#     Range : 0 ... 555359 =      0.000 ...  1388.398 secs
# Ready.
# Loaded file: C14_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C25_preprocessed-raw.fif...
#     Range : 0 ... 722239 =      0.000 ...  1805.598 secs
# Ready.
# Loaded file: C25_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/035_preprocessed-raw.fif...
#     Range : 0 ... 693599 =      0.000 ...  1733.997 secs
# Ready.
# Loaded file: 035_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C26_preprocessed-raw.fif...
#     Range : 0 ... 978239 =      0.000 ...  2445.597 secs
# Ready.
# Loaded file: C26_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/043_preprocessed-raw.fif...
#     Range : 0 ... 595679 =      0.000 ...  1489.197 secs
# Ready.
# Loaded file: 043_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/021_preprocessed-raw.fif...
#     Range : 0 ... 1225759 =      0.000 ...  3064.398 secs
# Ready.
# Loaded file: 021_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/029_preprocessed-raw.fif...
#     Range : 0 ... 946399 =      0.000 ...  2365.997 secs
# Ready.
# Loaded file: 029_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/038_preprocessed-raw.fif...
#     Range : 0 ... 571679 =      0.000 ...  1429.197 secs
# Ready.
# Loaded file: 038_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C2._preprocessed-raw.fif...
#     Range : 0 ... 886879 =      0.000 ...  2217.198 secs
# Ready.
# Loaded file: C2._preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C19_preprocessed-raw.fif...
#     Range : 0 ... 537919 =      0.000 ...  1344.797 secs
# Ready.
# Loaded file: C19_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C5._preprocessed-raw.fif...
#     Range : 0 ... 642879 =      0.000 ...  1607.197 secs
# Ready.
# Loaded file: C5._preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/020_preprocessed-raw.fif...
#     Range : 0 ... 928639 =      0.000 ...  2321.597 secs
# Ready.
# Loaded file: 020_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/059_preprocessed-raw.fif...
#     Range : 0 ... 829599 =      0.000 ...  2073.997 secs
# Ready.
# Loaded file: 059_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/034_preprocessed-raw.fif...
#     Range : 0 ... 685279 =      0.000 ...  1713.197 secs
# Ready.
# Loaded file: 034_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/007_preprocessed-raw.fif...
#     Range : 0 ... 593200 =      0.000 ...  1483.000 secs
# Ready.
# Loaded file: 007_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/032_preprocessed-raw.fif...
#     Range : 0 ... 760159 =      0.000 ...  1900.398 secs
# Ready.
# Loaded file: 032_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/018_preprocessed-raw.fif...
#     Range : 0 ... 1183839 =      0.000 ...  2959.597 secs
# Ready.
# Loaded file: 018_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/040_preprocessed-raw.fif...
#     Range : 0 ... 535839 =      0.000 ...  1339.598 secs
# Ready.
# Loaded file: 040_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C17_preprocessed-raw.fif...
#     Range : 0 ... 575359 =      0.000 ...  1438.398 secs
# Ready.
# Loaded file: C17_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/008_preprocessed-raw.fif...
#     Range : 0 ... 712799 =      0.000 ...  1781.997 secs
# Ready.
# Loaded file: 008_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C16_preprocessed-raw.fif...
#     Range : 0 ... 528799 =      0.000 ...  1321.997 secs
# Ready.
# Loaded file: C16_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/C6._preprocessed-raw.fif...
#     Range : 0 ... 714239 =      0.000 ...  1785.598 secs
# Ready.
# Loaded file: C6._preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/030_preprocessed-raw.fif...
#     Range : 0 ... 765759 =      0.000 ...  1914.398 secs
# Ready.
# Loaded file: 030_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/010_preprocessed-raw.fif...
#     Range : 0 ... 799120 =      0.000 ...  1997.800 secs
# Ready.
# Loaded file: 010_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/041_preprocessed-raw.fif...
#     Range : 0 ... 529759 =      0.000 ...  1324.398 secs
# Ready.
# Loaded file: 041_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/057_preprocessed-raw.fif...
#     Range : 0 ... 786559 =      0.000 ...  1966.398 secs
# Ready.
# Loaded file: 057_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/024_preprocessed-raw.fif...
#     Range : 0 ... 768479 =      0.000 ...  1921.197 secs
# Ready.
# Loaded file: 024_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/054_preprocessed-raw.fif...
#     Range : 0 ... 747839 =      0.000 ...  1869.598 secs
# Ready.
# Loaded file: 054_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/045_preprocessed-raw.fif...
#     Range : 0 ... 617599 =      0.000 ...  1543.997 secs
# Ready.
# Loaded file: 045_preprocessed-raw.fif
# Opening raw data file /run/user/1000/gvfs/smb-share:server=research-cifs.nyumc.org,share=research/jwanglab/jwanglabspace/George Kenefati/Chronic Low Back Pain Study/Data/Processed Data/051_preprocessed-raw.fif...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 9
#       7 for file_name in raw_fif_files:
#       8     file_path = os.path.join(data_path, file_name)
# ----> 9     raw = read_raw_fif(file_path, preload = False)
#      10     print(f"Loaded file: {file_name}")
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/io/fiff/raw.py:543, in read_raw_fif(fname, allow_maxshield, preload, on_split_missing, verbose)
#     502 @fill_doc
#     503 def read_raw_fif(
#     504     fname, allow_maxshield=False, preload=False, on_split_missing="raise", verbose=None
#     505 ):
#     506     """Reader function for Raw FIF data.
#     507
#     508     Parameters
#    (...)
#     541     are updated accordingly.
#     542     """
# --> 543     return Raw(
#     544         fname=fname,
#     545         allow_maxshield=allow_maxshield,
#     546         preload=preload,
#     547         verbose=verbose,
#     548         on_split_missing=on_split_missing,
#     549     )
#
# File <decorator-gen-284>:12, in __init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/io/fiff/raw.py:105, in Raw.__init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#     103 next_fname = fname
#     104 while next_fname is not None:
# --> 105     raw, next_fname, buffer_size_sec = self._read_raw_file(
#     106         next_fname, allow_maxshield, preload, do_check_ext
#     107     )
#     108     do_check_ext = False
#     109     raws.append(raw)
#
# File <decorator-gen-285>:12, in _read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/io/fiff/raw.py:197, in Raw._read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#     195     whole_file = True
#     196 fname_rep = _get_fname_rep(fname)
# --> 197 ff, tree, _ = fiff_open(fname, preload=whole_file)
#     198 with ff as fid:
#     199     #   Read the measurement info
#     201     info, meas = read_meas_info(fid, tree, clean_bads=True)
#
# File <decorator-gen-6>:12, in fiff_open(fname, preload, verbose)
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/_fiff/open.py:128, in fiff_open(fname, preload, verbose)
#     126 fid = _fiff_get_fid(fname)
#     127 try:
# --> 128     return _fiff_open(fname, fid, preload)
#     129 except Exception:
#     130     fid.close()
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/_fiff/open.py:183, in _fiff_open(fname, fid, preload)
#     181 while tag.next >= 0:
#     182     pos = fid.tell()
# --> 183     tag = read_tag_info(fid)
#     184     if tag is None:
#     185         break  # HACK : to fix file ending with empty tag...
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/_fiff/tag.py:79, in read_tag_info(fid)
#      77 def read_tag_info(fid):
#      78     """Read Tag info (or header)."""
# ---> 79     tag = _read_tag_header(fid)
#      80     if tag is None:
#      81         return None
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/_fiff/tag.py:162, in _read_tag_header(fid)
#     160 def _read_tag_header(fid):
#     161     """Read only the header of a Tag."""
# --> 162     s = fid.read(4 * 4)
#     163     if len(s) != 16:
#     164         where = fid.tell() - len(s)
#
# KeyboardInterrupt:

# %%
raw.copy().pick(picks = "stim").plot(start = 3, duration = 6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 raw.copy().pick(picks = "stim").plot(start = 3, duration = 6)
#
# File <decorator-gen-124>:12, in pick(self, picks, exclude, verbose)
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/channels/channels.py:503, in UpdateChannelsMixin.pick(self, picks, exclude, verbose)
#     484 @verbose
#     485 def pick(self, picks, exclude=(), *, verbose=None):
#     486     """Pick a subset of channels.
#     487
#     488     Parameters
#    (...)
#     501         The modified instance.
#     502     """
# --> 503     picks = _picks_to_idx(self.info, picks, "all", exclude, allow_empty=False)
#     504     self._pick_drop_channels(picks)
#     506     # remove dropped channel types from reject and flat
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/_fiff/pick.py:1271, in _picks_to_idx(info, picks, none, exclude, allow_empty, with_ref_meg, return_kind, picks_on)
#    1269     raise ValueError("picks must be 1D, got %sD" % (picks.ndim,))
#    1270 if picks.dtype.char in ("S", "U"):
# -> 1271     picks = _picks_str_to_idx(
#    1272         info,
#    1273         picks,
#    1274         exclude,
#    1275         with_ref_meg,
#    1276         return_kind,
#    1277         extra_repr,
#    1278         allow_empty,
#    1279         orig_picks,
#    1280     )
#    1281     if return_kind:
#    1282         picked_ch_type_or_generic = picks[1]
#
# File ~/anaconda3/envs/mne/lib/python3.11/site-packages/mne/_fiff/pick.py:1409, in _picks_str_to_idx(info, picks, exclude, with_ref_meg, return_kind, extra_repr, allow_empty, orig_picks)
#    1407 if sum(any_found) == 0:
#    1408     if not allow_empty:
# -> 1409         raise ValueError(
#    1410             "picks (%s) could not be interpreted as "
#    1411             'channel names (no channel "%s"), channel types (no '
#    1412             'type "%s" present), or a generic type (just "all" or "data")'
#    1413             % (repr(orig_picks) + extra_repr, str(bad_names), bad_type)
#    1414         )
#    1415     picks = np.array([], int)
#    1416 elif sum(any_found) > 1:
#
# ValueError: picks ('stim') could not be interpreted as channel names (no channel "['stim']"), channel types (no type "['stim']" present), or a generic type (just "all" or "data")

# %%
# viable subjects
sub_ids = utils.import_subs(data_path)
# select only files ending in raw.fif
#sub_ids = sub_ids[7:] #this is remnant from George
print(sub_ids)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # viable subjects
# ----> 2 sub_ids = utils.import_subs(data_path)
#       3 # select only files ending in raw.fif
#       4 #sub_ids = sub_ids[7:] #this is remnant from George
#       5 print(sub_ids)
#
# File /media/sb10flpc002/08e63286-43ce-4f61-9491-1ed048c96f20/Rachel Wu/eeg-projects/Code/eeg_toolkit/eeg_toolkit/utils.py:32, in import_subs(data_path)
#      29 def import_subs(data_path="../Data/Processed Data/"):
#      30     # import sub_ids
#      31     sub_ids=[]
# ---> 32     with open('sub_ids.txt', 'r') as file:
#      33         for line in file:
#      34             # Check if the line is not commented out
#      35             if not line.strip().startswith('#'):
#      36                 # Extracting the subject ID and ignoring any comments or trailing commas
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sub_ids.txt'

# %%
#Checking the files we pulled, give me the names
print(f"Chronics: {len([el for el in sub_ids if el.startswith('0')])}")
print(f"Controls: {len([el for el in sub_ids if el.startswith('C')])}")
print(f"Total: {len(sub_ids)}")

# %%
for sub_id in sub_ids:
#loop through the data
#Load data

# %%
#Try accessing raw data in this cell to understand attributes
#load_data
#
