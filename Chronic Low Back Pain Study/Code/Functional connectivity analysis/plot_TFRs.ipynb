# %% [markdown]
# ### Use subject processor to plot TFRs

# %%
import sys
import os
from pathlib import Path
sys.path.append('/home/wanglab/Documents/George Kenefati/Code/eeg_toolkit/')
from eeg_toolkit.subject_processor import SubjectProcessor, Subject, SubjectGroup
from eeg_toolkit import preprocess

# %% [markdown]
# ### Paths

# %%
# sl_method = 'dSPM'
sl_method = 'MNE'

# %%
# Settings
times_tup, time_win_path = preprocess.get_time_window(5)

# data paths
data_dir = Path("../../Data")
processed_data_path = data_dir / "Processed Data"
stc_path = data_dir / f"Source Time Courses ({sl_method})"
EO_resting_data_path = stc_path / "Eyes Open"
EC_resting_data_path = stc_path / "Eyes Closed"
zscored_epochs_data_path = stc_path / "zscored_Epochs" / time_win_path

# save paths
subset = "Representative TFR"
fc_path = data_dir / f"Functional Connectivity ({sl_method})"
fc_subset_path = fc_path / subset
save_path = fc_subset_path
os.makedirs(save_path, exist_ok=True)

# set up paths_dict for processor
paths_dict = {
    "processed_data_path": processed_data_path,
    "stc_path": stc_path,
    "EO_resting_data_path": EO_resting_data_path,
    "EC_resting_data_path": EC_resting_data_path,
    "zscored_epochs_data_path": zscored_epochs_data_path,
    "save_path": save_path
}
# Out:
# [-2.5,0.0,2.5]

# %% [markdown]
# ### Manually enter age/sex matched subjects

# %%
# All CP and HC subs
sub_ids_CP = [  
    '018',
    '022',
    '024',
    '031',
    '032',
    '034',
    '036',
    '039',
    '040',
    '045',
    '046',
    '052', 
    '020',  
    '021',  
    '023',  
    '029',  
    '037',  
    '041',  
    '042',  
    '044',  
    '048',  
    '049',  
    '050',  
    # '056' 
]

sub_ids_HC = [
    'C10',  
    'C11',  
    'C12',  
    'C13',  
    'C14',  
    'C15',  
    'C16',  
    'C17',  
    'C18',  
    'C19',  
    'C2.',  
    'C24',  
    'C25',  
    'C26',  
    'C27',  
    'C3.',  
    'C6.',  
    'C7.',  
    'C9.'  
]
  
# CP Subs with widespread pain
sub_ids_WSP = [
    '018',
    '022',
    '024',
    '031',
    '032',
    '034',
    '036',
    '039',
    '040',
    '045',
    '046',
    '052',
]

# CP Subs with localized pain
sub_ids_LP = [  
    '020',  
    '021',  
    '023',  
    '029',  
    '044',  
    '037',  
    '041',  
    '042',  
    '048',  
    '049',  
    '050',  
    '056'  
]

# %% [markdown]
# ### Define ROIs, frequency bands, conditions, and methods for FC

# %%
####################################################################
# REGIONS OF INTEREST
# Get stc only from selected labels
roi_names = [# Left
             'rostralanteriorcingulate-lh', # Left Rostral ACC
             'caudalanteriorcingulate-lh', # Left Caudal ACC
             'postcentral-lh', # Left S1,
             'insula-lh', 'superiorfrontal-lh', # Left Insula, Left DL-PFC,
             'medialorbitofrontal-lh', # Left Medial-OFC
            #  # CONTROLS
            #  # lateral occipital
            #  'lateraloccipital-lh', # Left Visual Cortex
            #  'superiortemporal-lh', # Left Auditory Cortex
             # Right
             'rostralanteriorcingulate-rh', # Right Rostral ACC
             'caudalanteriorcingulate-rh', # Right Caudal ACC
             'postcentral-rh', # , Right S1
             'insula-rh', 'superiorfrontal-rh', # Right Insula, Right DL-PFC
             'medialorbitofrontal-rh', # Right Medial-OFC
            #  # CONTROLS
            #  'lateraloccipital-rh', # Right Visual Cortex
            #  'superiortemporal-rh', # Right Auditory Cortex
]

# Write out ROI names as acronyms
roi_acronyms = ["rACC-lh", "dACC-lh", "S1-lh", 
                "insula-lh", "dlPFC-lh", "mOFC-lh", 
                # # Controls
                # "lOCC-lh", "aud-lh",
                "rACC-rh", "dACC-rh", "S1-rh", 
                "insula-rh", "dlPFC-rh", "mOFC-rh", 
                # # Controls
                # "lOCC-rh", "aud-rh"
               ]

####################################################################
# BANDS OF INTEREST
Freq_Bands = { # Narrower bands and overlaps
        # 'delta': [0, 4],
        "theta": [4.0, 8.0],
        "alpha": [8.0, 13.0],
        "beta": [13.0, 30.0],
        "low-gamma": [30.0, 58.5],
        # # "notch": [58.5, 61.5],
        "high-gamma": [61.5, 100.0],
    }
band_names = [band for band in Freq_Bands]

####################################################################
# CONDITIONS
conditions = [
    "Hand 256 mN",
    # "Back 32 mN",
    # 'Back LS',
    # "Back 256 mN",
    "Eyes Open",
    # "Eyes Closed",
]

# %%
# Choose a subject list to focus on 
sub_ids_focus = sub_ids_CP

# Channel
channel = "Cz"

# Time range
time_range=(-0.2, 0.8)
# time_range=(0., 1.)

# Baseline
baseline=(-2.5, 0)

# TFR vlim range
vlim = (-7, 7)
vlim = (-5, 5)

# %% [markdown]
# ### Chronic Pain Group

# %%
# Create an instance of SubjectProcessor
processor = SubjectProcessor(paths_dict, roi_acronyms)

# Loop through each subject and process the response
subjects = [Subject(sub_id) for sub_id in sub_ids_focus]
subject_group = SubjectGroup(subjects)

tfr, evoked_data_arrays = processor.plot_TFR_and_trace(subject_group,
                             channel=channel, 
                             baseline=baseline,
                             time_range=time_range,
                             vlim=vlim,
                            )
# Out:
# Loading data for 23 subjects...
# Subjects: ['018', '022', '024', '031', '032', '034', '036', '039', '040', '045', '046', '052', '020', '021', '023', '029', '037', '041', '042', '044', '048', '049', '050']
#
# Loading Epochs for 018...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/018_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 018...
# Loaded 73 stimulus labels
# 20 hand trials (out of 73)
#
# Loading Epochs for 022...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/022_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 022...
# Loaded 56 stimulus labels
# 10 hand trials (out of 56)
#
# Loading Epochs for 024...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/024_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 024...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 031...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/031_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 031...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 032...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/032_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 41 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 032...
# Loaded 41 stimulus labels
# 7 hand trials (out of 41)
#
# Loading Epochs for 034...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/034_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 034...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 036...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/036_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 57 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 036...
# Loaded 57 stimulus labels
# 10 hand trials (out of 57)
#
# Loading Epochs for 039...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/039_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 52 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 039...
# Loaded 52 stimulus labels
# 10 hand trials (out of 52)
#
# Loading Epochs for 040...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/040_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 040...
# Loaded 56 stimulus labels
# 10 hand trials (out of 56)
#
# Loading Epochs for 045...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/045_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 045...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 046...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/046_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 046...
# Loaded 59 stimulus labels
# 9 hand trials (out of 59)
#
# Loading Epochs for 052...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/052_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 052...
# Loaded 59 stimulus labels
# 10 hand trials (out of 59)
#
# Loading Epochs for 020...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/020_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 020...
# Loaded 80 stimulus labels
# 20 hand trials (out of 80)
#
# Loading Epochs for 021...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/021_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 110 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 021...
# Loaded 110 stimulus labels
# 17 hand trials (out of 110)
#
# Loading Epochs for 023...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/023_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 023...
# Loaded 55 stimulus labels
# 10 hand trials (out of 55)
#
# Loading Epochs for 029...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/029_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 029...
# Loaded 48 stimulus labels
# 10 hand trials (out of 48)
#
# Loading Epochs for 037...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/037_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 43 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 037...
# Loaded 43 stimulus labels
# 6 hand trials (out of 43)
#
# Loading Epochs for 041...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/041_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 041...
# Loaded 59 stimulus labels
# 9 hand trials (out of 59)
#
# Loading Epochs for 042...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/042_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 042...
# Loaded 68 stimulus labels
# 15 hand trials (out of 68)
#
# Loading Epochs for 044...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/044_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 35 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 044...
# Loaded 35 stimulus labels
# 5 hand trials (out of 35)
#
# Loading Epochs for 048...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/048_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 048...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 049...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/049_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 049...
# Loaded 54 stimulus labels
# 10 hand trials (out of 54)
#
# Loading Epochs for 050...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/050_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 58 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 050...
# Loaded 58 stimulus labels
# 10 hand trials (out of 58)
# Loading data for 23 subjects...
# Subjects: ['018', '022', '024', '031', '032', '034', '036', '039', '040', '045', '046', '052', '020', '021', '023', '029', '037', '041', '042', '044', '048', '049', '050']
#
# Loading Epochs for 018...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/018_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 018...
# Loaded 73 stimulus labels
# 20 hand trials (out of 73)
#
# Loading Epochs for 022...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/022_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 022...
# Loaded 56 stimulus labels
# 10 hand trials (out of 56)
#
# Loading Epochs for 024...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/024_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 024...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 031...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/031_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 031...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 032...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/032_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 41 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 032...
# Loaded 41 stimulus labels
# 7 hand trials (out of 41)
#
# Loading Epochs for 034...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/034_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 034...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 036...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/036_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 57 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 036...
# Loaded 57 stimulus labels
# 10 hand trials (out of 57)
#
# Loading Epochs for 039...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/039_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 52 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 039...
# Loaded 52 stimulus labels
# 10 hand trials (out of 52)
#
# Loading Epochs for 040...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/040_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 040...
# Loaded 56 stimulus labels
# 10 hand trials (out of 56)
#
# Loading Epochs for 045...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/045_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 045...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 046...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/046_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 046...
# Loaded 59 stimulus labels
# 9 hand trials (out of 59)
#
# Loading Epochs for 052...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/052_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 052...
# Loaded 59 stimulus labels
# 10 hand trials (out of 59)
#
# Loading Epochs for 020...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/020_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 020...
# Loaded 80 stimulus labels
# 20 hand trials (out of 80)
#
# Loading Epochs for 021...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/021_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 110 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 021...
# Loaded 110 stimulus labels
# 17 hand trials (out of 110)
#
# Loading Epochs for 023...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/023_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 023...
# Loaded 55 stimulus labels
# 10 hand trials (out of 55)
#
# Loading Epochs for 029...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/029_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 029...
# Loaded 48 stimulus labels
# 10 hand trials (out of 48)
#
# Loading Epochs for 037...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/037_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 43 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 037...
# Loaded 43 stimulus labels
# 6 hand trials (out of 43)
#
# Loading Epochs for 041...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/041_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 041...
# Loaded 59 stimulus labels
# 9 hand trials (out of 59)
#
# Loading Epochs for 042...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/042_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 042...
# Loaded 68 stimulus labels
# 15 hand trials (out of 68)
#
# Loading Epochs for 044...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/044_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 35 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 044...
# Loaded 35 stimulus labels
# 5 hand trials (out of 35)
#
# Loading Epochs for 048...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/048_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 048...
# Loaded 60 stimulus labels
# 10 hand trials (out of 60)
#
# Loading Epochs for 049...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/049_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 049...
# Loaded 54 stimulus labels
# 10 hand trials (out of 54)
#
# Loading Epochs for 050...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/050_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 58 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 050...
# Loaded 58 stimulus labels
# 10 hand trials (out of 58)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)

# %% [markdown]
# ### Individual subjects, Chronic Pain

# %%
# Create an instance of SubjectProcessor
processor = SubjectProcessor(paths_dict, roi_acronyms)

# Loop through each subject and process the response
for sub_id in sub_ids_focus:
    subject = Subject(sub_id)
    processor.plot_TFR_and_trace(subject,
                                 channel=channel, 
                                 baseline=baseline,
                                 time_range=time_range,
                                 vlim=vlim,
                                 )
    processor.process_response(subject)
    # break

# Display the results
processor.display_results()
# Out:
# Loading Epochs for 018...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/018_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 018...
# Loaded 73 stimulus labels
# 20 hand trials (out of 73)
#
# Loading Epochs for 018...
# Reading /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Functional connectivity analysis/../../Data/Processed Data/018_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =   -2500.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading STC epochs for 018...
# Loaded 73 stimulus labels
# 20 hand trials (out of 73)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 13
#       6     subject = Subject(sub_id)
#       7     processor.plot_TFR_and_trace(subject,
#       8                                  channel=channel,
#       9                                  baseline=baseline,
#      10                                  time_range=time_range,
#      11                                  vlim=vlim,
#      12                                  )
# ---> 13     processor.process_response(subject)
#      14     # break
#      15
#      16 # Display the results
#      17 processor.display_results()
#
# File ~/Documents/George Kenefati/Code/eeg_toolkit/eeg_toolkit/subject_processor.py:482, in SubjectProcessor.process_response(self, subject)
#     481 def process_response(self, subject: Subject):
# --> 482     response = self._get_user_response()
#     483     if response == "yes":
#     484         self.yes_list.append(subject.subject_id)
#
# File ~/Documents/George Kenefati/Code/eeg_toolkit/eeg_toolkit/subject_processor.py:474, in SubjectProcessor._get_user_response(self)
#     470 def _get_user_response(self) -> str:
#     471     response = input(
#     472         "Is this subject a candidate for representative TFR? (yes/no/maybe): "
#     473     )
# --> 474     assert response.lower() in [
#     475         "yes",
#     476         "no",
#     477         "maybe",
#     478     ], "Response must be 'yes', 'no', or 'maybe'"
#     479     return response.lower()
#
# AssertionError: Response must be 'yes', 'no', or 'maybe'

# %% [markdown]
# ### Healthy Control Group

# %%
# Choose a subject list to focus on 
# sub_ids_focus = sub_ids_HC

# %%
# # Create an instance of SubjectProcessor
# processor = SubjectProcessor(paths_dict, roi_acronyms)

# # Loop through each subject and process the response
# subjects = [Subject(sub_id) for sub_id in sub_ids_focus]
# subject_group = SubjectGroup(subjects)

# tfr, evoked_data_arrays = processor.plot_TFR_and_trace(subject_group,
#                              channel=channel, 
#                              baseline=baseline,
#                              time_range=time_range,
#                              vlim=vlim,
#                             )
