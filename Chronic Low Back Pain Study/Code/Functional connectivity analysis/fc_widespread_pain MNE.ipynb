# %% [markdown]
# ## FC for Widespread Pain Subjects
# #### Input: *stc.mat
# ####  Output: con, visualization

# %%
import os
from pathlib import Path
import sys
import mne 
import numpy as np
from mne.datasets import fetch_fsaverage
from tabulate import tabulate
fs_dir = fetch_fsaverage(verbose=True)
subject = "fsaverage"
subjects_dir = os.path.dirname(fs_dir)
sys.path.append("/home/wanglab/Documents/George Kenefati/Code/eeg_toolkit/")
from eeg_toolkit import preprocess, utils
import eeg_toolkit.functional_connectivity as fc
# Out:
# 0 files missing from root.txt in /home/wanglab/mne_data/MNE-fsaverage-data
# 0 files missing from bem.txt in /home/wanglab/mne_data/MNE-fsaverage-data/fsaverage
# 0 files missing from root.txt in /home/wanglab/mne_data/MNE-fsaverage-data
# 0 files missing from bem.txt in /home/wanglab/mne_data/MNE-fsaverage-data/fsaverage

# %% [markdown]
# ### Paths

# %%
# sl_method = input("Source Localization Method (1- MNE or 2- dSPM): ")
# sl_method = 'MNE' if sl_method == '1' else 'dSPM'
sl_method = 'MNE'
# sl_method = 'dSPM'

# %%
# Settings
times_tup, time_win_path = preprocess.get_time_window(5)

# data paths
data_dir = Path("../../Data")
processed_data_path = data_dir / "Processed Data"
stc_path = data_dir / f"Source Time Courses ({sl_method})"
EO_resting_data_path = stc_path / "Eyes Open"
EC_resting_data_path = stc_path / "Eyes Closed"
zscored_epochs_data_path = stc_path / "zscored_Epochs" / time_win_path

# save paths
subset = "Widespread_Pain"
fc_path = data_dir / f"Functional Connectivity ({sl_method})"
fc_subset_path = fc_path / subset
save_path = fc_subset_path

os.makedirs(save_path, exist_ok=True)
# Out:
# [-2.5,0.0,2.5]

# %% [markdown]
# ### Get subset of subjects with and without widespread pain

# %% [markdown]
# ### Manually enter age/sex matched subjects

# %%
# All CP and HC subs
sub_ids_CP = [  
    '018',  
    '020',  
    '021',  
    '027',  
    '031',  
    '032',  
    '033',  
    '035',  
    '036',  
    '037',  
    '038',  
    '040',  
    '043',  
    '044',  
    '048',  
    '049',  
    '050',  
    '057',  
    '059',
]

sub_ids_HC = [
    'C10',  
    'C11',  
    'C12',  
    'C13',  
    'C14',  
    'C15',  
    'C16',  
    'C17',  
    'C18',  
    'C19',  
    'C2.',  
    'C24',  
    'C25',  
    'C26',  
    'C27',  
    'C3.',  
    'C6.',  
    'C7.',  
    'C9.'  
]  
sub_ids = sub_ids_CP + sub_ids_HC

# TODO: temporary-- These subjects have no keypresses and thus no resting timestamps, but they do have epoched data
NO_KEYPRESS = ['045', 'C1.', 'C5.', 'C8.', 'C20', 'C21', 'C22']
sub_ids = [sub for sub in sub_ids if sub not in NO_KEYPRESS]

# CP Subs with widespread pain
sub_ids_CP_WSP = [
    '018',
    '022',
    '024',
    '031',
    '032',
    '034',
    '036',
    '039',
    '040',
    # '045', # TODO: add back in when timestamps ready
    '046',
    '052',
]

# CP Subs with localized pain
sub_ids_CP_LP = [  
    '020',  
    '021',  
    '023',  
    '029',  
    '031',  
    '037',  
    '041',  
    '042',  
    '048',  
    '049',  
    '050',  
    '056'  
]

# %%
# # viable subjects
# sub_ids = utils.import_subs(data_dir, "sub_ids.txt")
# sub_ids = sorted(sub_ids[7:])  # select only 64ch subs and turn into set

# Exclude HEALTHY subjects with widespread pain
widespread_pain_HC = ['C1.','C23']
sub_ids_HC = [sub for sub in sub_ids_HC if sub not in widespread_pain_HC]

# Exclude subjects with low trial count
# TODO: figure out how to skip
# C5 i think missing resting but has X trials
# sub_ids_CP_WSP.remove('055') 
# 036 has 6; 037 has 6, 044 has 5, 056 has 5, 058 has 4 (Localized pain)
# sub_ids_CP_LP.remove(['036', '037', '044', '056', '058'])

# %%
print(f"Chronics (all): {len(sub_ids_CP)}")
print([el for el in sub_ids_CP])
print(f"Chronics with widespread pain: {len(sub_ids_CP_WSP)}")
print([el for el in sub_ids_CP_WSP])
print(f"Chronics with localized pain: {len(sub_ids_CP_LP)}")
print([sub for sub in sub_ids_CP_LP])
print(f"Controls: {len(sub_ids_HC)}")
print([el for el in sub_ids_HC])
print(f"\nTotal (Chronics + Controls): {len(sub_ids)}")
# Out:
# Chronics (all): 19
# ['018', '020', '021', '027', '031', '032', '033', '035', '036', '037', '038', '040', '043', '044', '048', '049', '050', '057', '059']
# Chronics with widespread pain: 11
# ['018', '022', '024', '031', '032', '034', '036', '039', '040', '046', '052']
# Chronics with localized pain: 12
# ['020', '021', '023', '029', '031', '037', '041', '042', '048', '049', '050', '056']
# Controls: 19
# ['C10', 'C11', 'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C2.', 'C24', 'C25', 'C26', 'C27', 'C3.', 'C6.', 'C7.', 'C9.']
#
# Total (Chronics + Controls): 38

# %% [markdown]
# ### Settings for conditions/bands/methods

# %%
# Settings
sfreq = 400  # Hz
tmin, tmax = 0.0, 1.25  # exclude the baseline period for connectivity estimation

# Use canonical bands or narrower bands
# narrow_bands = False 
narrow_bands = True 

# Choose which connectivity estimates to run. "amplitude", "phase", or "both"
# method_choice = "phase"
method_choice = "both"

# Include intermediate stimulus?
include_LS = False

# Load previously saved group data
load_group_data_flag = False
# load_group_data_flag = True

# Save group data?
# save_group_data_flag = False
save_group_data_flag = True

# Evoked only or include resting too?
include_resting = True
# include_resting = False

# %% [markdown]
# ### Define ROIs, frequency bands, conditions, and methods for FC

# %%
####################################################################
# REGIONS OF INTEREST
roi_names = [  # Left
    "rostralanteriorcingulate-lh",  # Left Rostral ACC
    "caudalanteriorcingulate-lh",  # Left Caudal ACC
    "postcentral-lh",  # Left S1,
    "insula-lh",
    "superiorfrontal-lh",  # Left Insula, Left DL-PFC,
    "medialorbitofrontal-lh",  # Left Medial-OFC
    # Right
    "rostralanteriorcingulate-rh",  # Right Rostral ACC
    "caudalanteriorcingulate-rh",  # Right Caudal ACC
    "postcentral-rh",  # , Right S1
    "insula-rh",
    "superiorfrontal-rh",  # Right Insula, Right DL-PFC
    "medialorbitofrontal-rh",
]  # Right Medial-OFC

# Write out ROI names as acronyms
roi_acronyms = ["rACC-lh", "dACC-lh", "S1-lh", "insula-lh", "dlPFC-lh", "mOFC-lh",
                "rACC-rh", "dACC-rh", "S1-rh", "insula-rh", "dlPFC-rh", "mOFC-rh"]


####################################################################
# BANDS OF INTEREST
if not narrow_bands:
    Freq_Bands = {
        # 'delta': [0, 4],
        "theta": [4.0, 8.0],
        # "alpha": [8.0, 13.0],
        # "beta": [13.0, 30.0],
        # "low-gamma": [30.0, 58.5],
        # # "notch": [58.5, 61.5],
        # "high-gamma": [61.5, 100.0],
    }
else:
    Freq_Bands = { # Narrower bands and overlaps
        # 'delta': [0, 4],
        "theta": [4.0, 8.0],
        "low-alpha": [8.0, 10.0],
        "high-alpha": [10.0, 13.0],
        # "low-beta": [13.0, 22.0],
        # "high-beta": [22.0, 30.0],
        "low-gamma-i": [30.0, 45.0],
        "low-gamma-ii": [45.0, 60.0],
        # # "notch": [58.5, 61.5],
        "high-gamma-i": [60.0, 80.0],
        "high-gamma-ii": [80.0, 100.0],
    }
band_names = [band for band in Freq_Bands]

####################################################################
# CONNECTIVITY METHODS
if method_choice == "phase":
    con_methods = ["wpli2_debiased",
                ]
elif method_choice == "amplitude":
    con_methods = [
        # "aec_pairwise",
        "aec_symmetric",
        ]
elif method_choice == "both":
    con_methods = [
    "wpli2_debiased",
    # "aec_pairwise",
    "aec_symmetric", # keep only symmetric for now
    ]
    
####################################################################
# CONDITIONS
conditions = (
    [
        "Hand 32 mN",
        "Hand 128 mN",
        "Hand 256 mN",
        "Back 32 mN",
        "Back 128 mN",
        "Back 256 mN",
        "Eyes Open",
        "Eyes Closed",
    ]
    if include_LS
    else [
        # "Hand 32 mN",
        # 'Hand LS',
        "Hand 256 mN",
        # "Back 32 mN",
        # 'Back LS',
        # "Back 256 mN",
        "Eyes Open",
        # "Eyes Closed",
    ]
)

# Choose to exclude resting state data
conditions = conditions if include_resting else [
    c for c in conditions if "Eyes" not in c
]

####################################################################
# CONDITION DICTIONARY
condition_dict = {
        "Hand 32 mN": 0,
        'Hand LS': 1,
        "Hand 256 mN": 2,
        "Back 32 mN": 3,
        'Back LS': 4,
        "Back 256 mN": 5,
        "Eyes Open": 6,
        "Eyes Closed": 7,
}

####################################################################
# GROUP NAMES
groups=['Chronic Pain with Widespread Pain','Chronic Pain', 'Healthy Control']

# %% [markdown]
# ### Compute functional connectivity for each subject in each group

# %%
# Healthy Control group
if not load_group_data_flag:
    sub_con_HC = {}
    for sub_id in sub_ids_HC:
        print(sub_id)
        sub_avg_cons = fc.compute_sub_avg_con(
            sub_id,
            "Healthy Control",
            processed_data_path,
            zscored_epochs_data_path,
            EO_resting_data_path,
            EC_resting_data_path,
            con_methods,
            conditions,
            condition_dict,
            roi_names,
            Freq_Bands,
            tmin,
            tmax,
            sfreq,
            include_LS=include_LS,
        )
        sub_con_HC[sub_id] = sub_avg_cons
    utils.clear_display()
# Out:
# C10
# Reading stimulus labels and pain ratings for Subject C10...
#
# *stim_labels length = 57*
# *pain_ratings_raw length = 57*
#
# +----------------+----------------+
# | Subject        | C10            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C10            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C10            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C10            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C10            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C10            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C10            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C10           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C10           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C10           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C10           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C10           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C10           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C10           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# C11
# Reading stimulus labels and pain ratings for Subject C11...
#
# *stim_labels length = 59*
# *pain_ratings_raw length = 59*
#
# +----------------+----------------+
# | Subject        | C11            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 9              |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C11            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 9              |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C11            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 9              |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C11            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 9              |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C11            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 9              |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C11            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 9              |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C11            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 9              |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C11           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C11           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C11           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C11           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C11           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C11           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C11           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# C12
# Reading stimulus labels and pain ratings for Subject C12...
#
# *stim_labels length = 60*
# *pain_ratings_raw length = 60*
#
# +----------------+----------------+
# | Subject        | C12            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C12            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C12            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C12            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C12            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C12            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C12            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C12           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C12           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C12           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C12           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C12           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C12           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C12           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# C13
# Reading stimulus labels and pain ratings for Subject C13...
#
# *stim_labels length = 60*
# *pain_ratings_raw length = 60*
#
# +----------------+----------------+
# | Subject        | C13            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C13            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# ...
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C7.           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# C9.
# Reading stimulus labels and pain ratings for Subject C9....
#
# *stim_labels length = 60*
# *pain_ratings_raw length = 60*
#
# +----------------+----------------+
# | Subject        | C9.            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C9.            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C9.            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C9.            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C9.            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C9.            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | C9.            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C9.           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C9.           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C9.           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C9.           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C9.           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C9.           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | C9.           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*

# %%
# Chronics (all) group
if not load_group_data_flag:
    sub_con_CP = {}
    for sub_id in sub_ids_CP:
        print(sub_id)
        sub_avg_cons = fc.compute_sub_avg_con(
            sub_id,
            "Chronic Pain",
            processed_data_path,
            zscored_epochs_data_path,
            EO_resting_data_path,
            EC_resting_data_path,
            con_methods,
            conditions,
            condition_dict,
            roi_names,
            Freq_Bands,
            tmin,
            tmax,
            sfreq,
            include_LS=include_LS,
        )
        sub_con_CP[sub_id] = sub_avg_cons
    utils.clear_display()
# Out:
# 018
# Reading stimulus labels and pain ratings for Subject 018...
#
# *stim_labels length = 73*
# *pain_ratings_raw length = 73*
#
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# 020
# Reading stimulus labels and pain ratings for Subject 020...
#
# *stim_labels length = 80*
# *pain_ratings_raw length = 80*
#
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# 021
# Reading stimulus labels and pain ratings for Subject 021...
#
# *stim_labels length = 110*
# *pain_ratings_raw length = 110*
#
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# ...
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 059            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 15             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 059            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 15             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 059            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 15             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 059            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 15             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 059            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 15             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 059            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 15             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 059           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 059           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 059           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 059           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 059           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 059           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 059           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*

# %%
# CLBP with WSP
if not load_group_data_flag:
    sub_con_CP_WSP = {}
    for sub_id in sub_ids_CP_WSP:
        print(sub_id)
        sub_avg_cons = fc.compute_sub_avg_con(
            sub_id,
            "Chronic Pain w/ WSP",
            processed_data_path,
            zscored_epochs_data_path,
            EO_resting_data_path,
            EC_resting_data_path,
            con_methods,
            conditions,
            condition_dict,
            roi_names,
            Freq_Bands,
            tmin,
            tmax,
            sfreq,
            include_LS=include_LS,
        )
        sub_con_CP_WSP[sub_id] = sub_avg_cons
        
    utils.clear_display()
# Out:
# 018
# Reading stimulus labels and pain ratings for Subject 018...
#
# *stim_labels length = 73*
# *pain_ratings_raw length = 73*
#
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 018            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 018           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# 022
# Reading stimulus labels and pain ratings for Subject 022...
#
# *stim_labels length = 56*
# *pain_ratings_raw length = 56*
#
# +----------------+----------------+
# | Subject        | 022            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 022            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 022            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 022            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 022            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 022            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 022            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 022           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 022           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 022           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 022           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 022           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 022           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 022           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# 024
# Reading stimulus labels and pain ratings for Subject 024...
#
# *stim_labels length = 60*
# *pain_ratings_raw length = 60*
#
# +----------------+----------------+
# | Subject        | 024            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 024            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 024            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 024            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 024            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 024            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 024            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 024           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 024           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 024           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 024           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 024           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 024           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# ...
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 046           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# 052
# Reading stimulus labels and pain ratings for Subject 052...
#
# *stim_labels length = 59*
# *pain_ratings_raw length = 59*
#
# +----------------+----------------+
# | Subject        | 052            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 052            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 052            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 052            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 052            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 052            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 052            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 052           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 052           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 052           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 052           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 052           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 052           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 052           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*

# %%
# CLBP with LP
if not load_group_data_flag:
    sub_con_CP_LP = {}
    for sub_id in sub_ids_CP_LP:
        print(sub_id)
        sub_avg_cons = fc.compute_sub_avg_con(
            sub_id,
            "Chronic Pain w/ Localized Pain",
            processed_data_path,
            zscored_epochs_data_path,
            EO_resting_data_path,
            EC_resting_data_path,
            con_methods,
            conditions,
            condition_dict,
            roi_names,
            Freq_Bands,
            tmin,
            tmax,
            sfreq,
            include_LS=include_LS,
        )
        sub_con_CP_LP[sub_id] = sub_avg_cons
        
    utils.clear_display()
# Out:
# 020
# Reading stimulus labels and pain ratings for Subject 020...
#
# *stim_labels length = 80*
# *pain_ratings_raw length = 80*
#
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 020            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 20             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     computing cross-spectral density for epoch 18
#     computing cross-spectral density for epoch 19
#     computing cross-spectral density for epoch 20
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 020           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# 021
# Reading stimulus labels and pain ratings for Subject 021...
#
# *stim_labels length = 110*
# *pain_ratings_raw length = 110*
#
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 021            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 17             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     computing cross-spectral density for epoch 11
#     computing cross-spectral density for epoch 12
#     computing cross-spectral density for epoch 13
#     computing cross-spectral density for epoch 14
#     computing cross-spectral density for epoch 15
#     computing cross-spectral density for epoch 16
#     computing cross-spectral density for epoch 17
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 021           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 021           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 021           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 021           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 021           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 021           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 021           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# 023
# Reading stimulus labels and pain ratings for Subject 023...
#
# *stim_labels length = 55*
# *pain_ratings_raw length = 55*
#
# +----------------+----------------+
# | Subject        | 023            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 023            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 023            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 023            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 023            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 023            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 023            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 023           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 023           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 023           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# ...
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 050           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# 056
# Reading stimulus labels and pain ratings for Subject 056...
#
# *stim_labels length = 58*
# *pain_ratings_raw length = 58*
#
# +----------------+----------------+
# | Subject        | 056            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | theta          |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 4.8Hz..8.0Hz (5 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 056            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-alpha      |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 8.8Hz..9.6Hz (2 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 056            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-alpha     |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 10.4Hz..12.8Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 056            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-i    |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 30.3Hz..44.7Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 056            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | low-gamma-ii   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 45.5Hz..59.9Hz (19 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 056            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-i   |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 60.7Hz..79.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+----------------+
# | Subject        | 056            |
# +----------------+----------------+
# | Condition      | Hand 256 mN    |
# +----------------+----------------+
# | Num. of epochs | 10             |
# +----------------+----------------+
# | Band           | high-gamma-ii  |
# +----------------+----------------+
# | Method         | wpli2_debiased |
# +----------------+----------------+
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 66 connections
#     using t=0.000s..1.250s for estimation (501 points)
#     frequencies: 80.6Hz..99.8Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing cross-spectral density for epoch 1
#     computing cross-spectral density for epoch 2
#     computing cross-spectral density for epoch 3
#     computing cross-spectral density for epoch 4
#     computing cross-spectral density for epoch 5
#     computing cross-spectral density for epoch 6
#     computing cross-spectral density for epoch 7
#     computing cross-spectral density for epoch 8
#     computing cross-spectral density for epoch 9
#     computing cross-spectral density for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]
# *con_epochs shape = (144, 1)*
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 056           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | theta         |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 4 - 8 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 8.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 056           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-alpha     |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 8 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 8.00, 10.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 056           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-alpha    |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 10 - 13 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 10.00, 13.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 056           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-i   |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 30 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 30.00, 45.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 056           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | low-gamma-ii  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 45 - 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 45.00, 60.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 056           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-i  |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 60 - 80 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 60.00, 80.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*
# +----------------+---------------+
# | Subject        | 056           |
# +----------------+---------------+
# | Condition      | Eyes Open     |
# +----------------+---------------+
# | Num. of epochs | 1             |
# +----------------+---------------+
# | Band           | high-gamma-ii |
# +----------------+---------------+
# | Method         | aec_symmetric |
# +----------------+---------------+
# label_ts shape =  (1, 12, 72001)
# ts shape = (12, 500)
# Setting up band-pass filter from 80 - 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 80.00, 100.00 Hz: -6.02, -6.02 dB
#
# *data shape = (12, 12)*

# %%
# Checkpoint path
checkpoint_path = save_path / f"Checkpoints: {[el for el in conditions]}"
os.makedirs(checkpoint_path, exist_ok=True)
print(f"Loading checkpoints from path: {checkpoint_path}")

if not load_group_data_flag:
    # Stack the connectivity of all subjects in each group
    group_con_HC = fc.compute_group_con(sub_con_HC, conditions, con_methods, band_names)
    group_con_CP = fc.compute_group_con(sub_con_CP, conditions, con_methods, band_names)
    group_con_CP_WSP = fc.compute_group_con(sub_con_CP_WSP, conditions, con_methods, band_names)
    group_con_CP_LP = fc.compute_group_con(sub_con_CP_LP, conditions, con_methods, band_names)
else:
    group_con_HC = utils.unpickle_data(checkpoint_path, f"group_con_{subset}_HC.pkl")
    group_con_CP = utils.unpickle_data(checkpoint_path, f"group_con_{subset}_CP.pkl")
    group_con_CP_WSP = utils.unpickle_data(checkpoint_path, f"group_con_{subset}_CP_WSP.pkl")
    group_con_CP_LP = utils.unpickle_data(checkpoint_path, f"group_con_{subset}_CP_LP.pkl")

    sub_con_HC = utils.unpickle_data(checkpoint_path, f"sub_con_{subset}_HC.pkl")
    sub_con_CP = utils.unpickle_data(checkpoint_path, f"sub_con_{subset}_CP.pkl")
    sub_con_CP_WSP = utils.unpickle_data(checkpoint_path, f"sub_con_{subset}_CP_WSP.pkl")
    sub_con_CP_LP = utils.unpickle_data(checkpoint_path, f"sub_con_{subset}_CP_LP.pkl")
# Out:
# Loading checkpoints from path: ../../Data/Functional Connectivity (MNE)/Widespread_Pain/Checkpoints: ['Hand 256 mN', 'Eyes Open']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 8
#       4 print(f"Loading checkpoints from path: {checkpoint_path}")
#       6 if not load_group_data_flag:
#       7     # Stack the connectivity of all subjects in each group
# ----> 8     group_con_HC = fc.compute_group_con(sub_con_HC, conditions, con_methods, band_names)
#       9     group_con_CP = fc.compute_group_con(sub_con_CP, conditions, con_methods, band_names)
#      10     group_con_CP_WSP = fc.compute_group_con(sub_con_CP_WSP, conditions, con_methods, band_names)
#
# File ~/Documents/George Kenefati/Code/eeg_toolkit/eeg_toolkit/functional_connectivity.py:532, in compute_group_con(sub_con_dict, conditions, con_methods, band_names)
#     528 for method in con_methods:
#     529     for band in band_names:
#     530         # Compute the average for all subjects
#     531         stack = np.stack(
# --> 532             [
#     533                 sub_con_dict[subject][condition][method][band]["data"]
#     534                 for subject in subjects
#     535             ],
#     536         )
#     538         # Add result to dictionary
#     539         if condition not in group_dict:
#
# File ~/Documents/George Kenefati/Code/eeg_toolkit/eeg_toolkit/functional_connectivity.py:533, in <listcomp>(.0)
#     528 for method in con_methods:
#     529     for band in band_names:
#     530         # Compute the average for all subjects
#     531         stack = np.stack(
#     532             [
# --> 533                 sub_con_dict[subject][condition][method][band]["data"]
#     534                 for subject in subjects
#     535             ],
#     536         )
#     538         # Add result to dictionary
#     539         if condition not in group_dict:
#
# KeyError: 'aec_symmetric'

# %%
if save_group_data_flag:
    # Save/checkpoint as pickle
    utils.pickle_data(checkpoint_path, f"sub_con_{subset}_HC.pkl", sub_con_HC)
    utils.pickle_data(checkpoint_path, f"group_con_{subset}_HC.pkl", group_con_HC)
    
    utils.pickle_data(checkpoint_path, f"sub_con_{subset}_CP.pkl", sub_con_CP)
    utils.pickle_data(checkpoint_path, f"group_con_{subset}_CP.pkl", group_con_CP)
    
    utils.pickle_data(checkpoint_path, f"sub_con_{subset}_CP_WSP.pkl", sub_con_CP_WSP)
    utils.pickle_data(checkpoint_path, f"group_con_{subset}_CP_WSP.pkl", group_con_CP_WSP)

    utils.pickle_data(checkpoint_path, f"sub_con_{subset}_CP_LP.pkl", sub_con_CP_LP)
    utils.pickle_data(checkpoint_path, f"group_con_{subset}_CP_LP.pkl", group_con_CP_LP)

# %% [markdown]
# ### Plot settings

# %% [markdown]
# ### Plot and compute satistics to assess statistical differences

# %%
# Highlight p-values with red box automatically
highlight_pvals=False

# Make any non-significant squares white
show_only_significant=True

# Set title automatically
set_title=True

# Show values in the matrix quadrants
show_fc_vals=True

# Round negative values to zero 
# (Vinck. et al 2011 has negative values for WPLI 2 Debiased. NO ROUNDING)
round_neg_vals=False

# Plot 3D brain visualization (for AEC only)
plot_brain=False

# %%
# CP Widespread Pain vs Healthy Control
these_group_names = ["Chronic Pain", "Healthy Control","Mann_Whitney_U_test"]
these_group_cons = [group_con_CP, group_con_HC]

for condition in conditions:
    # Make a directory for the stats
    stats_save_path = save_path / f"CP_vs_HC_{condition}"
    os.makedirs(stats_save_path, exist_ok=True)

    for method in con_methods:
        for band in band_names:
            # Ignore some specific condition/method combinations
            if "Hand" in condition and "AEC" in method:
                continue
            elif "Eyes" in condition and "wpli" in method:
                continue
            
            # Select groups for mann-whitney
            print(f"{condition} - {these_group_names[0]} vs. {these_group_names[1]} - {method} - {band}")

            # For each of the top 3 connections, add the connection, its frequency, and its mean strength to a list  
            for group_con,group_name in zip(these_group_cons, these_group_names):
                table_data = []  
                top_3_info = group_con[condition][method][band]["top 3"] 
                print(f"Top 3 Connections in {group_name} group")
                for i in range(3):  
                    connection = top_3_info["connections"][i]  
                    frequency = top_3_info["frequency"][i]  
                    mean_strength = top_3_info["mean strength"][i]  
                    table_data.append([f"{roi_acronyms[connection[0]]} <-> {roi_acronyms[connection[1]]}", frequency, mean_strength])  
                
                # Define table headers  
                headers = ['Connection', 'Frequency', 'Mean Strength']  
                
                # Print the table  
                print(tabulate(table_data, headers, tablefmt='pretty'),'\n')  

            group1_stack = these_group_cons[0][condition][method][band]["data"]
            group2_stack = these_group_cons[1][condition][method][band]["data"]

            nepochs_1 = these_group_cons[0][condition]['num_epochs']
            nepochs_2 = these_group_cons[1][condition]['num_epochs']
            print(f"Num epochs: {nepochs_1} vs. {nepochs_2}")

            # Compute the Mann-Whitney U test
            p_values, means_1, sem_1, means_2, sem_2 = fc.mann_whitney_test(
                group1_stack, 
                group2_stack,
                roi_names,
                round_neg_vals=round_neg_vals,
                method=method)

            # Need to custom set this because the colors blow out
            if "aec" in method and "Eyes" in condition:
                vmin = 0.0
                vmax = 0.6
            else:
                vmin = None
                vmax = None

            # Plotting            
            # Gather the information for plotting
            plot_kwargs= dict(
                method=method,
                band=band, 
                roi_names=roi_names,
                roi_acronyms=roi_acronyms,
                condition=condition,
                vmin=vmin,
                vmax=vmax,
                group_names=these_group_names,
                nepochs=[nepochs_1, nepochs_2],
                titles=[these_group_names[0], 
                        these_group_names[1],
                        "CP vs. HC",],
                save_names=["Mann_Whitney_U_test",
                            these_group_names[0], 
                            these_group_names[1],
                            ],
                save_path=stats_save_path,
                )           

            fc.plot_connectivity_and_stats(means_1=means_1,
                                           means_2=means_2,
                                           sem_1=sem_1,
                                           sem_2=sem_2,
                                           p_values=p_values,
                                           **plot_kwargs,
                                           save_fig=True,
                                           highlight_pvals=highlight_pvals,
                                           min_fc_val=None,
                                           set_title=set_title,
                                           show_fc_vals=show_fc_vals,
                                           round_neg_vals=round_neg_vals,
            )
            
            if "aec" in method and plot_brain:
                # Convert ROI names to labels
                labels = [
                    mne.read_labels_from_annot(
                        subject, regexp=roi, subjects_dir=subjects_dir
                    )[0]
                    for roi in roi_names
                ]

                # Load the inverse1
                inv = None
                if "Eyes" not in condition:
                    inv = utils.unpickle_data(
                        zscored_epochs_data_path, f"{sub_id}_inv.pkl"
                    )
                elif condition == "Eyes Open":
                    inv = utils.unpickle_data(
                        EO_resting_data_path, f"{sub_id}_inv.pkl"
                    )
                elif condition == "Eyes Closed":
                    inv = utils.unpickle_data(
                        EC_resting_data_path, f"{sub_id}_inv.pkl"
                    )

                fc.plot_degree(
                    p_values, 
                    title=f"{plot_kwargs['titles'][0]} | {condition} | {band} | ({method} method, {nepochs_1} vs. {nepochs_2} trials)",
                    labels=labels, 
                    inv=inv,
                )
                fc.plot_degree(
                    means_1, 
                    title=f"{plot_kwargs['titles'][1]} | {condition} | {band} | ({method} method, {nepochs_1} trials)",
                    labels=labels, 
                    inv=inv,
                )
                fc.plot_degree(
                    means_2, 
                    title=f"{plot_kwargs['titles'][2]} | {condition} | {band} | ({method} method, {nepochs_2} trials)",
                    labels=labels, 
                    inv=inv,
                )

# %%
# CP Widespread Pain vs CP without Widespread Pain
these_group_names = ["CP w/ Widespread Pain", "CP with Localized Pain","Mann_Whitney_U_test"]
these_group_cons = [group_con_CP_WSP, group_con_CP_LP]

for condition in conditions:
    # Make a directory for the stats
    stats_save_path = save_path / f"CP_WSP_vs_CP_LP_{condition}"
    os.makedirs(stats_save_path, exist_ok=True)

    for method in con_methods:
        for band in band_names:
            # Ignore some specific condition/method combinations
            if "Hand" in condition and "AEC" in method:
                continue
            elif "Eyes" in condition and "wpli" in method:
                continue
            
            # Select groups for mann-whitney
            print(f"{condition} - {these_group_names[0]} vs. {these_group_names[1]} - {method} - {band}")

            # For each of the top 3 connections, add the connection, its frequency, and its mean strength to a list  
            for group_con,group_name in zip(these_group_cons, these_group_names):
                table_data = []  
                top_3_info = group_con[condition][method][band]["top 3"] 
                print(f"Top 3 Connections in {group_name} group")
                for i in range(3):  
                    connection = top_3_info["connections"][i]  
                    frequency = top_3_info["frequency"][i]  
                    mean_strength = top_3_info["mean strength"][i]  
                    table_data.append([f"{roi_acronyms[connection[0]]} <-> {roi_acronyms[connection[1]]}", frequency, mean_strength])  
                
                # Define table headers  
                headers = ['Connection', 'Frequency', 'Mean Strength']  
                
                # Print the table  
                print(tabulate(table_data, headers, tablefmt='pretty'),'\n')  

            group1_stack = these_group_cons[0][condition][method][band]["data"]
            group2_stack = these_group_cons[1][condition][method][band]["data"]

            nepochs_1 = these_group_cons[0][condition]['num_epochs']
            nepochs_2 = these_group_cons[1][condition]['num_epochs']
            print(f"Num epochs: {nepochs_1} vs. {nepochs_2}")
            
            # Compute the Mann-Whitney U test
            p_values, means_1, sem_1, means_2, sem_2 = fc.mann_whitney_test(
                group1_stack,
                group2_stack,
                roi_names,
                round_neg_vals=round_neg_vals,
                method=method)

            # Need to custom set this
            if "aec" in method and "Eyes" in condition:
                vmin = 0.0
                vmax = 0.6
            else:
                vmin = None
                vmax = None

            # Plotting            
            # Gather the information for plotting
            plot_kwargs= dict(
                method=method,
                band=band, 
                roi_names=roi_names,
                roi_acronyms=roi_acronyms,
                condition=condition,
                vmin=vmin,
                vmax=vmax,
                group_names=these_group_names,
                nepochs=[nepochs_1, nepochs_2],
                titles=[these_group_names[0], 
                        these_group_names[1],
                        "CP w/ WSP vs. CP w/ LP",],
                save_names=["Mann_Whitney_U_test",
                            these_group_names[0], 
                            these_group_names[1],
                            ],
                save_path=stats_save_path,
                )
                                
            fc.plot_connectivity_and_stats(means_1=means_1,
                                           means_2=means_2,
                                           sem_1=sem_1,
                                           sem_2=sem_2,
                                           p_values=p_values,
                                           **plot_kwargs,
                                           save_fig=True,
                                           highlight_pvals=highlight_pvals,
                                           min_fc_val=None,
                                           set_title=set_title,
                                           show_fc_vals=show_fc_vals,
                                           round_neg_vals=round_neg_vals,
            )
        
            if "aec" in method and plot_brain:
                # Convert ROI names to labels
                labels = [
                    mne.read_labels_from_annot(
                        subject, regexp=roi, subjects_dir=subjects_dir
                    )[0]
                    for roi in roi_names
                ]

                # Load the inverse
                inv = None
                if "Eyes" not in condition:
                    inv = utils.unpickle_data(
                        zscored_epochs_data_path, f"{sub_id}_inv.pkl"
                    )
                elif condition == "Eyes Open":
                    inv = utils.unpickle_data(
                        EO_resting_data_path, f"{sub_id}_inv.pkl"
                    )
                elif condition == "Eyes Closed":
                    inv = utils.unpickle_data(
                        EC_resting_data_path, f"{sub_id}_inv.pkl"
                    )

                fc.plot_degree(
                    p_values, 
                    title=f"{plot_kwargs['titles'][0]} | {condition} | {band} | ({method} method, {nepochs_1} vs. {nepochs_2} trials)",
                    labels=labels, 
                    inv=inv,
                )
                fc.plot_degree(
                    means_1, 
                    title=f"{plot_kwargs['titles'][1]} | {condition} | {band} | ({method} method, {nepochs_1} trials)",
                    labels=labels, 
                    inv=inv,
                )
                fc.plot_degree(
                    means_2, 
                    title=f"{plot_kwargs['titles'][2]} | {condition} | {band} | ({method} method, {nepochs_2} trials)",
                    labels=labels, 
                    inv=inv,
                )

# %% [markdown]
# ## Plot individual data in each group

# %% [markdown]
# ### Plot settings

# %%
exit()

# %%
# CP Widespread Pain
this_group_name = "Chronic Pain"
this_group_cons = sub_con_CP
n=len(roi_names)

done_subs=['018','020','021','022','024','027',
           '031','032','033','035','036']

subs_gen = (sub_id for sub_id in this_group_cons if sub_id not in done_subs)

for sub_id in subs_gen:
    for condition in conditions:
        # Make a directory for the stats
        stats_save_path = save_path / f"CP_individual_{condition}"
        os.makedirs(stats_save_path, exist_ok=True)
        for method in con_methods:
            for band in band_names:
                # Select groups for mann-whitney
                print(f"{condition} - {sub_id} - {this_group_name} - {method} - {band}")
                group1_stack = this_group_cons[sub_id][condition][method][band]["data"]
                nepochs_1 = this_group_cons[sub_id][condition]['num_epochs']
                print(f"Num epochs: {nepochs_1}")

                # Plotting
                # Gather the information for plotting
                plot_kwargs= dict(
                    method=method,
                    band=band, 
                    roi_names=roi_names,
                    roi_acronyms=roi_acronyms,
                    condition=condition,
                    group_names=this_group_name,
                    nepochs=[nepochs_1],
                    titles=[f"Subject {sub_id} - {condition} - {method} - {band} ({nepochs_1} trials)"],
                    save_names=[this_group_name],
                    save_path=stats_save_path,
                    )
            
                fc.plot_connectivity_and_stats(
                    means_1=group1_stack,
                    **plot_kwargs,
                    save_fig=True,
                    highlight_pvals=highlight_pvals,
                    show_only_significant=show_only_significant,
                    min_fc_val=None,
                    set_title=set_title,
                    show_fc_vals=show_fc_vals,
                    round_neg_vals=round_neg_vals,
                )

                if "aec" in method and plot_brain:
                    # Convert ROI names to labels
                    labels = [
                        mne.read_labels_from_annot(
                            subject, regexp=roi, subjects_dir=subjects_dir
                        )[0]
                        for roi in roi_names
                    ]

                    # Load the inverse
                    inv = None
                    if "Eyes" not in condition:
                        inv = utils.unpickle_data(zscored_epochs_data_path,
                                                  f"{sub_id}_inv.pkl"
                        )
                    elif condition == "Eyes Open":
                        inv = utils.unpickle_data(EO_resting_data_path,
                                                  f"{sub_id}_inv.pkl"
                        )
                    elif condition == "Eyes Closed":
                        inv = utils.unpickle_data(EC_resting_data_path,
                                                  f"{sub_id}_inv.pkl"
                        )

                    fc.plot_degree(
                        p_values, 
                        title=f"{plot_kwargs['titles'][0]} | {condition} | {band} | ({method} method, {nepochs_1} vs. {nepochs_2} trials)",
                        labels=labels, 
                        inv=inv,
                    )
                    fc.plot_degree(
                        means_1, 
                        title=f"{plot_kwargs['titles'][1]} | {condition} | {band} | ({method} method, {nepochs_1} trials)",
                        labels=labels, 
                        inv=inv,
                    )
                    fc.plot_degree(
                        means_2, 
                        title=f"{plot_kwargs['titles'][2]} | {condition} | {band} | ({method} method, {nepochs_2} trials)",
                        labels=labels, 
                        inv=inv,
                    )

# %%
# CP Widespread Pain
this_group_name = "Healthy Control"
this_group_cons = sub_con_HC
n=len(roi_names)

done_subs=[]

subs_gen = (sub_id for sub_id in this_group_cons if sub_id not in done_subs)

for sub_id in subs_gen:
    for condition in conditions:
        # Make a directory for the stats
        stats_save_path = save_path / f"CP_individual_{condition}"
        os.makedirs(stats_save_path, exist_ok=True)
        for method in con_methods:
            for band in band_names:
                # Select groups for mann-whitney
                print(f"{condition} - {sub_id} - {this_group_name} - {method} - {band}")
                group1_stack = this_group_cons[sub_id][condition][method][band]["data"]
                nepochs_1 = this_group_cons[sub_id][condition]['num_epochs']
                print(f"Num epochs: {nepochs_1}")

                # Plotting
                # Gather the information for plotting
                plot_kwargs= dict(
                    method=method,
                    band=band, 
                    roi_names=roi_names,
                    roi_acronyms=roi_acronyms,
                    condition=condition,
                    group_names=this_group_name,
                    nepochs=[nepochs_1],
                    titles=[f"Subject {sub_id} - {condition} - {method} - {band} ({nepochs_1} trials)"],
                    save_names=[this_group_name],
                    save_path=stats_save_path,
                    )
            
                fc.plot_connectivity_and_stats(
                    means_1=group1_stack,
                    **plot_kwargs,
                    save_fig=True,
                    highlight_pvals=highlight_pvals,
                    show_only_significant=show_only_significant,
                    min_fc_val=None,
                    set_title=set_title,
                    show_fc_vals=show_fc_vals,
                    round_neg_vals=round_neg_vals,
                )

                if "aec" in method and plot_brain:
                    # Convert ROI names to labels
                    labels = [
                        mne.read_labels_from_annot(
                            subject, regexp=roi, subjects_dir=subjects_dir
                        )[0]
                        for roi in roi_names
                    ]

                    # Load the inverse
                    inv = None
                    if "Eyes" not in condition:
                        inv = utils.unpickle_data(zscored_epochs_data_path,
                                                  f"{sub_id}_inv.pkl"
                        )
                    elif condition == "Eyes Open":
                        inv = utils.unpickle_data(EO_resting_data_path,
                                                  f"{sub_id}_inv.pkl"
                        )
                    elif condition == "Eyes Closed":
                        inv = utils.unpickle_data(EC_resting_data_path,
                                                  f"{sub_id}_inv.pkl"
                        )

                    fc.plot_degree(
                        p_values, 
                        title=f"{plot_kwargs['titles'][0]} | {condition} | {band} | ({method} method, {nepochs_1} vs. {nepochs_2} trials)",
                        labels=labels, 
                        inv=inv,
                    )
                    fc.plot_degree(
                        means_1, 
                        title=f"{plot_kwargs['titles'][1]} | {condition} | {band} | ({method} method, {nepochs_1} trials)",
                        labels=labels, 
                        inv=inv,
                    )
                    fc.plot_degree(
                        means_2, 
                        title=f"{plot_kwargs['titles'][2]} | {condition} | {band} | ({method} method, {nepochs_2} trials)",
                        labels=labels, 
                        inv=inv,
                    )
