# %% [markdown]
# # Export to vhdr in order to visually inspect and remove artifacts by snips

# %%
import os
import mne
from pathlib import Path
import numpy as np
import preprocess_resting as pr

# %%
# Paths
data_path = Path("../../Data")
processed_data_path = data_path / 'Processed Data'
resting_save_path = processed_data_path / 'Cropped noisy spans'
os.makedirs(resting_save_path, exist_ok=True)

# %% [markdown]
# ## Load processed eyes open

# %% [markdown]
# ### Crop noisy spans

# %%
# MAKE SURE TO COMMENT ONCE THIS IS RUN ONCE.
# IF FORGET, CHECK FOR THE NOISY SPAN IN SIGVIEWER
sub_ids = {
    '033': [(246.5,248)],
    '040': [(0.,11.)],
    'C19': [(15.,16)],
    'C16': [(275.5,277.5),
            (280.4,280.8),
            (281.2,281.8),],
    'C15': [(249.5,251.25)],
    'C13': [(2.,3.5),
            (14.25,16.),
            (18.5,19.5),
            (142,143),
            (146.5,148),
            (255.5,260),],
    'C12': [(113.5,115.5)],
    'C11': [(56.3,58),
            (62,62.5),
            (114.7,117),
            (155.2,156),
            (157.5,159),
            (241.5,243.7),],
    'C9.': [(5.3,7.5),
           (40,42.8),
           (132,136),
           (184.5,189),
           (261.2,265.5),
           (293.5,295),],
    '050': [(58.2,59.5),
            (203.7,206.3)],
    'C7.': [(88.5,90.5),
           (272,274),],
    'C6.': [(70.2,75.8)],
    'C2.': [(0,1),
            (5,8),
            (15.5,16.5),
            (222.5,223),
            (224,224.5),],
    '059': [(37.3,38.5),
            (162.2,163.6),
            (221.2,223.5),
            (305,)],
}

# %%
check_done = True
check_done = False

# %%
for sub_id in sub_ids:
    if check_done and os.path.exists(resting_save_path / f'{sub_id}_eyes_open-raw.fif'):
        print(f'Subject {sub_id} already cropped')
        continue
    print(f'Subject {sub_id}: cropping noisy spans')

    # Load eyes open raw
    raw_eo = mne.io.read_raw_fif(processed_data_path / f'{sub_id}_eyes_open-raw.fif')

    # Keep track of total time cropped
    total_time_cropped = 0
    
    # Crop based on provided times
    # reverse_sub_ids = sub_ids[sub_id][::-1]
    reverse_sub_ids = sub_ids[sub_id]
    for i, crop_times in enumerate(reverse_sub_ids):
        print(f'Subject {sub_id}: cropping {i+1} of {len(sub_ids[sub_id])}: {crop_times}')
          
        # Adjust crop_times by subtracting the total time cropped  
        crop_times_adjusted = [crop_time - total_time_cropped for crop_time in crop_times] 
        crop_times = crop_times_adjusted
        
        # get crop times
        t1=crop_times[0]
        t2=crop_times[1] if len(crop_times) == 2 else None

        # if only one time is given use that as end time
        if t2 is None:
            raw_eo = raw_eo.crop(tmax=t1)
        else:
            raw_eo = pr.snip_span(raw_eo, t1, t2)  
            
    # Save cropped raw        
    raw_eo.export(resting_save_path / f'{sub_id}_eyes_open.vhdr', overwrite=True)
    raw_eo.save(resting_save_path / f'{sub_id}_eyes_open-raw.fif', overwrite=True)
    print(f"Subject {sub_id} noisy span cropped")
# Out:
# Subject 033: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/033_eyes_open-raw.fif...
#     Range : 150477 ... 275653 =    376.192 ...   689.133 secs
# Ready.
# Subject 033: cropping 1 of 1: (246.5, 248)
# Creating RawArray with float64 data, n_channels=64, n_times=124577
#     Range : 0 ... 124576 =      0.000 ...   311.440 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/033_eyes_open-raw.fif
# /home/wanglab/mambaforge/envs/mne/lib/python3.11/site-packages/pybv/_export.py:61: RuntimeWarning: Encountered data in 'double' format. Converting to float32.
#   warn(
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/033_eyes_open-raw.fif
# [done]
# Subject 033 noisy span cropped
# Subject 040: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/040_eyes_open-raw.fif...
#     Range : 158438 ... 278638 =    396.095 ...   696.595 secs
# Ready.
# Subject 040: cropping 1 of 1: (0.0, 11.0)
# Creating RawArray with float64 data, n_channels=64, n_times=115801
#     Range : 0 ... 115800 =      0.000 ...   289.500 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/040_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/040_eyes_open-raw.fif
# [done]
# Subject 040 noisy span cropped
# Subject C19: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C19_eyes_open-raw.fif...
#     Range : 144181 ... 264221 =    360.452 ...   660.553 secs
# Ready.
# Subject C19: cropping 1 of 1: (15.0, 16)
# Creating RawArray with float64 data, n_channels=64, n_times=119641
#     Range : 0 ... 119640 =      0.000 ...   299.100 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C19_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C19_eyes_open-raw.fif
# [done]
# Subject C19 noisy span cropped
# Subject C16: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C16_eyes_open-raw.fif...
#     Range : 157158 ... 279101 =    392.895 ...   697.753 secs
# Ready.
# Subject C16: cropping 1 of 3: (275.5, 277.5)
# Creating RawArray with float64 data, n_channels=64, n_times=121144
#     Range : 0 ... 121143 =      0.000 ...   302.858 secs
# Ready.
# Subject C16: cropping 2 of 3: (280.4, 280.8)
# Creating RawArray with float64 data, n_channels=64, n_times=120984
#     Range : 0 ... 120983 =      0.000 ...   302.457 secs
# Ready.
# Subject C16: cropping 3 of 3: (281.2, 281.8)
# Creating RawArray with float64 data, n_channels=64, n_times=120744
#     Range : 0 ... 120743 =      0.000 ...   301.858 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C16_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C16_eyes_open-raw.fif
# [done]
# Subject C16 noisy span cropped
# Subject C15: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C15_eyes_open-raw.fif...
#     Range : 162998 ... 284901 =    407.495 ...   712.253 secs
# Ready.
# Subject C15: cropping 1 of 1: (249.5, 251.25)
# Creating RawArray with float64 data, n_channels=64, n_times=121204
#     Range : 0 ... 121203 =      0.000 ...   303.007 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C15_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C15_eyes_open-raw.fif
# [done]
# Subject C15 noisy span cropped
# Subject C13: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C13_eyes_open-raw.fif...
#     Range : 159078 ... 281920 =    397.695 ...   704.800 secs
# Ready.
# Subject C13: cropping 1 of 6: (2.0, 3.5)
# Creating RawArray with float64 data, n_channels=64, n_times=122243
#     Range : 0 ... 122242 =      0.000 ...   305.605 secs
# Ready.
# Subject C13: cropping 2 of 6: (14.25, 16.0)
# Creating RawArray with float64 data, n_channels=64, n_times=121543
#     Range : 0 ... 121542 =      0.000 ...   303.855 secs
# Ready.
# Subject C13: cropping 3 of 6: (18.5, 19.5)
# Creating RawArray with float64 data, n_channels=64, n_times=121143
#     Range : 0 ... 121142 =      0.000 ...   302.855 secs
# Ready.
# Subject C13: cropping 4 of 6: (142, 143)
# Creating RawArray with float64 data, n_channels=64, n_times=120743
#     Range : 0 ... 120742 =      0.000 ...   301.855 secs
# Ready.
# Subject C13: cropping 5 of 6: (146.5, 148)
# Creating RawArray with float64 data, n_channels=64, n_times=120143
#     Range : 0 ... 120142 =      0.000 ...   300.355 secs
# Ready.
# Subject C13: cropping 6 of 6: (255.5, 260)
# Creating RawArray with float64 data, n_channels=64, n_times=118343
#     Range : 0 ... 118342 =      0.000 ...   295.855 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C13_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C13_eyes_open-raw.fif
# [done]
# Subject C13 noisy span cropped
# Subject C12: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C12_eyes_open-raw.fif...
#     Range : 173421 ... 294261 =    433.553 ...   735.653 secs
# Ready.
# Subject C12: cropping 1 of 1: (113.5, 115.5)
# Creating RawArray with float64 data, n_channels=64, n_times=120041
#     Range : 0 ... 120040 =      0.000 ...   300.100 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C12_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C12_eyes_open-raw.fif
# [done]
# Subject C12 noisy span cropped
# Subject C11: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C11_eyes_open-raw.fif...
#     Range : 148699 ... 269860 =    371.748 ...   674.650 secs
# Ready.
# Subject C11: cropping 1 of 6: (56.3, 58)
# Creating RawArray with float64 data, n_channels=64, n_times=120482
#     Range : 0 ... 120481 =      0.000 ...   301.202 secs
# Ready.
# Subject C11: cropping 2 of 6: (62, 62.5)
# Creating RawArray with float64 data, n_channels=64, n_times=120282
#     Range : 0 ... 120281 =      0.000 ...   300.702 secs
# Ready.
# Subject C11: cropping 3 of 6: (114.7, 117)
# Creating RawArray with float64 data, n_channels=64, n_times=119362
#     Range : 0 ... 119361 =      0.000 ...   298.402 secs
# Ready.
# Subject C11: cropping 4 of 6: (155.2, 156)
# Creating RawArray with float64 data, n_channels=64, n_times=119042
#     Range : 0 ... 119041 =      0.000 ...   297.603 secs
# Ready.
# Subject C11: cropping 5 of 6: (157.5, 159)
# Creating RawArray with float64 data, n_channels=64, n_times=118442
#     Range : 0 ... 118441 =      0.000 ...   296.103 secs
# Ready.
# Subject C11: cropping 6 of 6: (241.5, 243.7)
# Creating RawArray with float64 data, n_channels=64, n_times=117562
#     Range : 0 ... 117561 =      0.000 ...   293.902 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C11_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C11_eyes_open-raw.fif
# [done]
# Subject C11 noisy span cropped
# Subject C9.: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C9._eyes_open-raw.fif...
#     Range : 160381 ... 288718 =    400.952 ...   721.795 secs
# Ready.
# Subject C9.: cropping 1 of 6: (5.3, 7.5)
# Creating RawArray with float64 data, n_channels=64, n_times=127458
#     Range : 0 ... 127457 =      0.000 ...   318.642 secs
# Ready.
# Subject C9.: cropping 2 of 6: (40, 42.8)
# Creating RawArray with float64 data, n_channels=64, n_times=126338
#     Range : 0 ... 126337 =      0.000 ...   315.842 secs
# Ready.
# Subject C9.: cropping 3 of 6: (132, 136)
# Creating RawArray with float64 data, n_channels=64, n_times=124738
#     Range : 0 ... 124737 =      0.000 ...   311.842 secs
# Ready.
# Subject C9.: cropping 4 of 6: (184.5, 189)
# Creating RawArray with float64 data, n_channels=64, n_times=122938
#     Range : 0 ... 122937 =      0.000 ...   307.342 secs
# Ready.
# Subject C9.: cropping 5 of 6: (261.2, 265.5)
# Creating RawArray with float64 data, n_channels=64, n_times=121218
#     Range : 0 ... 121217 =      0.000 ...   303.043 secs
# Ready.
# Subject C9.: cropping 6 of 6: (293.5, 295)
# Creating RawArray with float64 data, n_channels=64, n_times=120618
#     Range : 0 ... 120617 =      0.000 ...   301.543 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C9._eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C9._eyes_open-raw.fif
# [done]
# Subject C9. noisy span cropped
# Subject 050: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/050_eyes_open-raw.fif...
#     Range : 150901 ... 273221 =    377.252 ...   683.053 secs
# Ready.
# Subject 050: cropping 1 of 2: (58.2, 59.5)
# Creating RawArray with float64 data, n_channels=64, n_times=121801
#     Range : 0 ... 121800 =      0.000 ...   304.500 secs
# Ready.
# Subject 050: cropping 2 of 2: (203.7, 206.3)
# Creating RawArray with float64 data, n_channels=64, n_times=120761
#     Range : 0 ... 120760 =      0.000 ...   301.900 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/050_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/050_eyes_open-raw.fif
# [done]
# Subject 050 noisy span cropped
# Subject C7.: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C7._eyes_open-raw.fif...
#     Range : 159741 ... 281838 =    399.353 ...   704.595 secs
# Ready.
# Subject C7.: cropping 1 of 2: (88.5, 90.5)
# Creating RawArray with float64 data, n_channels=64, n_times=121298
#     Range : 0 ... 121297 =      0.000 ...   303.243 secs
# Ready.
# Subject C7.: cropping 2 of 2: (272, 274)
# Creating RawArray with float64 data, n_channels=64, n_times=120498
#     Range : 0 ... 120497 =      0.000 ...   301.243 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C7._eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C7._eyes_open-raw.fif
# [done]
# Subject C7. noisy span cropped
# Subject C6.: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C6._eyes_open-raw.fif...
#     Range : 198141 ... 320136 =    495.353 ...   800.340 secs
# Ready.
# Subject C6.: cropping 1 of 1: (70.2, 75.8)
# Creating RawArray with float64 data, n_channels=64, n_times=119756
#     Range : 0 ... 119755 =      0.000 ...   299.387 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C6._eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C6._eyes_open-raw.fif
# [done]
# Subject C6. noisy span cropped
# Subject C2.: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/C2._eyes_open-raw.fif...
#     Range : 134541 ... 279017 =    336.353 ...   697.543 secs
# Ready.
# Subject C2.: cropping 1 of 5: (0, 1)
# Creating RawArray with float64 data, n_channels=64, n_times=144077
#     Range : 0 ... 144076 =      0.000 ...   360.190 secs
# Ready.
# Subject C2.: cropping 2 of 5: (5, 8)
# Creating RawArray with float64 data, n_channels=64, n_times=142877
#     Range : 0 ... 142876 =      0.000 ...   357.190 secs
# Ready.
# Subject C2.: cropping 3 of 5: (15.5, 16.5)
# Creating RawArray with float64 data, n_channels=64, n_times=142477
#     Range : 0 ... 142476 =      0.000 ...   356.190 secs
# Ready.
# Subject C2.: cropping 4 of 5: (222.5, 223)
# Creating RawArray with float64 data, n_channels=64, n_times=142277
#     Range : 0 ... 142276 =      0.000 ...   355.690 secs
# Ready.
# Subject C2.: cropping 5 of 5: (224, 224.5)
# Creating RawArray with float64 data, n_channels=64, n_times=142077
#     Range : 0 ... 142076 =      0.000 ...   355.190 secs
# Ready.
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C2._eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/C2._eyes_open-raw.fif
# [done]
# Subject C2. noisy span cropped
# Subject 059: cropping noisy spans
# Opening raw data file ../../Data/Processed Data/059_eyes_open-raw.fif...
#     Range : 130360 ... 283814 =    325.900 ...   709.535 secs
# Ready.
# Subject 059: cropping 1 of 4: (37.3, 38.5)
# Creating RawArray with float64 data, n_channels=64, n_times=152975
#     Range : 0 ... 152974 =      0.000 ...   382.435 secs
# Ready.
# Subject 059: cropping 2 of 4: (162.2, 163.6)
# Creating RawArray with float64 data, n_channels=64, n_times=152415
#     Range : 0 ... 152414 =      0.000 ...   381.035 secs
# Ready.
# Subject 059: cropping 3 of 4: (221.2, 223.5)
# Creating RawArray with float64 data, n_channels=64, n_times=151495
#     Range : 0 ... 151494 =      0.000 ...   378.735 secs
# Ready.
# Subject 059: cropping 4 of 4: (305,)
# Overwriting existing file.
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/059_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Chronic Low Back Pain Study/Code/Preprocessing and source localization/../../Data/Processed Data/Cropped noisy spans/059_eyes_open-raw.fif
# [done]
# Subject 059 noisy span cropped

# %%
reverse_sub_ids
# Out:
# [(37.3, 38.5), (162.2, 163.6), (221.2, 223.5), (305,)]
