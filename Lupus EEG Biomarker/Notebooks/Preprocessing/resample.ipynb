# %% [markdown]
# # Resample from 600 to 400 Hz because Source Localization crashes

# %%
import os
import mne
from pathlib import Path
import numpy as np
import preprocess

# %%
# Paths
data_path = Path("../../Data")
processed_data_path = data_path / 'Processed Data'

# %%
sub_ids = [
    '5186',
    '5295',
    '5648',
    '5675',
    '5873',
    '6100',
    '6106',
    '6310',
]

# %% [markdown]
# ### Load hdf5 files, filter, notch, and export to vhdr

# %%
resampled_path = data_path / 'Resampled'
resampled_path.mkdir(parents=True, exist_ok=True)

# %%
RESAMPLE_FREQ = 400

# %%
for sub_id in sub_ids:
    # Check if sub is done, if so, skip
    if not os.path.exists(resampled_path / f'{sub_id}_preprocessed-raw.fif'):
        print(f'Subject {sub_id} Full Recording')
        # Load raw
        raw = mne.io.read_raw_fif(processed_data_path / f'{sub_id}_preprocessed-raw.fif')
        # Resample
        raw = raw.resample(RESAMPLE_FREQ)
        # Save
        raw.save(resampled_path / f'{sub_id}_preprocessed-raw.fif')
        
    # Eyes open
    if not os.path.exists(resampled_path / f'{sub_id}_eyes_open-raw.fif'):
        print(f'Subject {sub_id} Eyes Open Recording')
        # Load raw
        raw = mne.io.read_raw_fif(processed_data_path / f'{sub_id}_eyes_open-raw.fif')
        # Resample
        raw = raw.resample(RESAMPLE_FREQ)
        # Save
        raw.save(resampled_path / f'{sub_id}_eyes_open-raw.fif')
        
    preprocess.clear_display()
# Out:
# Subject 6310 Full Recording
# Opening raw data file ../../Data/Processed Data/6310_preprocessed-raw.fif...
#     Range : 600 ... 1040447 =      1.000 ...  1734.078 secs
# Ready.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Resampled/6310_preprocessed-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Resampled/6310_preprocessed-raw.fif
# [done]
# Subject 6310 Eyes Open Recording
# Opening raw data file ../../Data/Processed Data/6310_eyes_open-raw.fif...
#     Range : 186001 ... 366373 =    310.002 ...   610.622 secs
# Ready.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Resampled/6310_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Resampled/6310_eyes_open-raw.fif
# [done]

# %% [markdown]
# ### Read processed data and raw EDF for annotations. Save cropped eyes open portion

# %%
missing_eyes_open_markers = []
for sub_id in sub_ids:
    #  Check if sub is done, if so, skip
    if os.path.exists(processed_data_path / f'{sub_id}_eyes_open-raw.fif'):
        print(f'Subject {sub_id} already processed, skipping...')
        continue
    
    print(f'Subject {sub_id}')
    # Processed FIF
    raw = mne.io.read_raw_fif(processed_data_path / f'{sub_id}_preprocessed-raw.fif')
    
    # Raw EDF with annotations
    raw_edf = preprocess.load_file(sub_id, data_path, extension="edf")
    events, event_ids = mne.events_from_annotations(raw_edf)
    
    # If missing eyes open
    if 'KB-Marker-0 (Eyes open) ' not in event_ids:
        missing_eyes_open_markers.append(sub_id)
        print(f"\nMissing eyes open marker for subject {sub_id}")

        # Set event_ids manually
        event_ids = {
                'KB-Marker-0 (Eyes open) ': 3,
                'KB-Marker-9 (END/STOP test) ': 7
                }

        # Set events manually on subject by subject basis
        sfreq = raw.info['sfreq']
        if sub_id == '5295':
            eyes_open_estimated_time = 182
            stop_estimated_time = eyes_open_estimated_time + 300
            events = np.array([
                [eyes_open_estimated_time*sfreq, 0,  3],
                [stop_estimated_time*sfreq, 0,  7],
            ] )
            
            # Crop eyes open and export to vhdr for plotting
            eyes_open = preprocess.crop_resting_EO(raw, sub_id, data_path, processed_data_path,
                                                   events=events, event_ids=event_ids)
            eyes_open.export(data_path / f'Subject {sub_id}' / 'eyes_open.vhdr', overwrite=True)
            print(f"Subject {sub_id} processed with manual eyes open events")
        else:
            continue
    
        # reset
        events, event_ids = None, None

    # Not missing eyes open
    else:
        # Crop eyes open and export to vhdr for plotting
        eyes_open = preprocess.crop_resting_EO(raw, sub_id, data_path, processed_data_path)
        eyes_open.export(data_path / f'Subject {sub_id}' / 'eyes_open.vhdr', overwrite=True)
        print(f"Subject {sub_id} processed")
    
print(missing_eyes_open_markers)
# Out:
# Subject 5186
# Opening raw data file ../../Data/Processed Data/5186_preprocessed-raw.fif...
#     Range : 600 ... 1150403 =      1.000 ...  1917.338 secs
# Ready.
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5186/5186 SLE test pinprick2024.04.09_14.29.43.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1150799  =      0.000 ...  1917.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 2 (32 mN pinprick) ', 'HA-2023.10.03-Trigger 4 (512 mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN forearm) ', 'KB-Marker-d (32 mN abdomen) ', 'KB-Marker-f (512 mN abdomen) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN forearm) ']
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5186/5186 SLE test pinprick2024.04.09_14.29.43.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1150799  =      0.000 ...  1917.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 2 (32 mN pinprick) ', 'HA-2023.10.03-Trigger 4 (512 mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN forearm) ', 'KB-Marker-d (32 mN abdomen) ', 'KB-Marker-f (512 mN abdomen) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN forearm) ']
#
# Eyes open found and next event STOP
#
# Eyes open times: [320.8016666666667, 621.2216666666667]
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5186_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5186_eyes_open-raw.fif
# [done]
# Overwriting existing file.
# Subject 5186 processed
# Subject 5295
# Opening raw data file ../../Data/Processed Data/5295_preprocessed-raw.fif...
#     Range : 600 ... 1137743 =      1.000 ...  1896.238 secs
# Ready.
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5295/5295 Lupus test pinprick2024.05.07_16.47.40.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1138199  =      0.000 ...  1896.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 10 (512 mN pinprick) ', 'HA-2023.10.03-Trigger 12 (32 mN pinprick) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN forearm) ', 'KB-Marker-d (32 mN abdomen) ', 'KB-Marker-f (512 mN abdomen) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-s (512 mN forearm) ']
#
# Missing eyes open marker for subject 5295
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5295/5295 Lupus test pinprick2024.05.07_16.47.40.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1138199  =      0.000 ...  1896.998 secs...
#
# Eyes open found and next event STOP
#
# Eyes open times: [182.0, 482.0]
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5295_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5295_eyes_open-raw.fif
# [done]
# Overwriting existing file.
# Subject 5295 processed with manual eyes open events
# Subject 5648
# Opening raw data file ../../Data/Processed Data/5648_preprocessed-raw.fif...
#     Range : 600 ... 1157855 =      1.000 ...  1929.758 secs
# Ready.
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5648/5648 Lupus test pinprick2024.02.11.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1157999  =      0.000 ...  1929.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 2 (32 mN pinprick) ', 'HA-2023.10.03-Trigger 4 (512 mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN MCP joint) ']
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5648/5648 Lupus test pinprick2024.02.11.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1157999  =      0.000 ...  1929.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 2 (32 mN pinprick) ', 'HA-2023.10.03-Trigger 4 (512 mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN MCP joint) ']
#
# Eyes open found and next event STOP
#
# Eyes open times: [228.18166666666667, 529.7016666666667]
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5648_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5648_eyes_open-raw.fif
# [done]
# Overwriting existing file.
# Subject 5648 processed
# Subject 5675
# Opening raw data file ../../Data/Processed Data/5675_preprocessed-raw.fif...
#     Range : 600 ... 1112195 =      1.000 ...  1853.658 secs
# Ready.
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5675/5675 Lupus test pinprick2024.05.08_17.27.41.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1112399  =      0.000 ...  1853.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 10 (512 mN pinprick) ', 'HA-2023.10.03-Trigger 12 (32 mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN forearm) ', 'KB-Marker-d (32 mN abdomen) ', 'KB-Marker-f (512 mN abdomen) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN forearm) ']
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5675/5675 Lupus test pinprick2024.05.08_17.27.41.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1112399  =      0.000 ...  1853.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 10 (512 mN pinprick) ', 'HA-2023.10.03-Trigger 12 (32 mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN forearm) ', 'KB-Marker-d (32 mN abdomen) ', 'KB-Marker-f (512 mN abdomen) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN forearm) ']
#
# Eyes open found but NO STOP found
#
# Eyes open times: [12.421666666666667, 312.4216666666667]
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5675_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5675_eyes_open-raw.fif
# [done]
# Overwriting existing file.
# Subject 5675 processed
# Subject 5873
# Opening raw data file ../../Data/Processed Data/5873_preprocessed-raw.fif...
#     Range : 600 ... 1036175 =      1.000 ...  1726.958 secs
# Ready.
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5873/5873 Lupus test pinprick2024.01.25_09.12.48.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1036199  =      0.000 ...  1726.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 2 (32 mN pinprick) ', 'HA-2023.10.03-Trigger 4 (512 mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-s (512 mN MCP joint) ']
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 5873/5873 Lupus test pinprick2024.01.25_09.12.48.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1036199  =      0.000 ...  1726.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 2 (32 mN pinprick) ', 'HA-2023.10.03-Trigger 4 (512 mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-s (512 mN MCP joint) ']
#
# Eyes open found and next event STOP
#
# Eyes open times: [226.32166666666666, 532.6416666666667]
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5873_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/5873_eyes_open-raw.fif
# [done]
# Overwriting existing file.
# Subject 5873 processed
# Subject 6100
# Opening raw data file ../../Data/Processed Data/6100_preprocessed-raw.fif...
#     Range : 600 ... 1043507 =      1.000 ...  1739.178 secs
# Ready.
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 6100/6100 Lupus test pinprick2024.02.20_11.30.40.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1043999  =      0.000 ...  1739.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 10 (512 mN pinprick) ', 'HA-2023.10.03-Trigger 12 (32  mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN MCP joint) ']
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 6100/6100 Lupus test pinprick2024.02.20_11.30.40.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1043999  =      0.000 ...  1739.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 10 (512 mN pinprick) ', 'HA-2023.10.03-Trigger 12 (32  mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN MCP joint) ']
#
# Eyes open found and next event STOP
#
# Eyes open times: [218.64166666666668, 521.8816666666667]
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/6100_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/6100_eyes_open-raw.fif
# [done]
# Overwriting existing file.
# Subject 6100 processed
# Subject 6106
# Opening raw data file ../../Data/Processed Data/6106_preprocessed-raw.fif...
#     Range : 600 ... 1019771 =      1.000 ...  1699.618 secs
# Ready.
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 6106/24_02_21 Lupus test pinprick2024.02.21_18.25.10.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1019999  =      0.000 ...  1699.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 10 (512 mN pinprick) ', 'HA-2023.10.03-Trigger 12 (32  mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN MCP joint) ']
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 6106/24_02_21 Lupus test pinprick2024.02.21_18.25.10.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1019999  =      0.000 ...  1699.998 secs...
# Used Annotations descriptions: ['HA-2023.10.03-Trigger 10 (512 mN pinprick) ', 'HA-2023.10.03-Trigger 12 (32  mN pinprick) ', 'KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN MCP joint) ']
#
# Eyes open found and FOLLOWING event STOP
#
# Eyes open times: [239.90166666666667, 541.9816666666667]
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/6106_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/6106_eyes_open-raw.fif
# [done]
# Overwriting existing file.
# Subject 6106 processed
# Subject 6310
# Opening raw data file ../../Data/Processed Data/6310_preprocessed-raw.fif...
#     Range : 600 ... 1040447 =      1.000 ...  1734.078 secs
# Ready.
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 6310/6310 SLE test pinprick2024.04.25_14.44.04.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1040999  =      0.000 ...  1734.998 secs...
# Used Annotations descriptions: ['KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN MCP joint) ']
# Extracting EDF parameters from /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Data/Subject 6310/6310 SLE test pinprick2024.04.25_14.44.04.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1040999  =      0.000 ...  1734.998 secs...
# Used Annotations descriptions: ['KB-Marker-0 (Eyes open) ', 'KB-Marker-1 (Eyes closed) ', 'KB-Marker-2 (256 mN forear...) ', 'KB-Marker-3 (256 mN forear...) ', 'KB-Marker-9 (END/STOP test) ', 'KB-Marker-a (32 mN MCP joint) ', 'KB-Marker-d (32 mN forearm) ', 'KB-Marker-f (512 mN forearm) ', 'KB-Marker-jj (256 mN MCP jo...) ', 'KB-Marker-k (256 mN MCP jo...) ', 'KB-Marker-m (TEST) ', 'KB-Marker-s (512 mN MCP joint) ']
#
# Eyes open found and next event STOP
#
# Eyes open times: [309.00166666666667, 609.6216666666667]
# Overwriting existing file.
# Writing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/6310_eyes_open-raw.fif
# Closing /home/wanglab/Documents/George Kenefati/Lupus EEG Biomarker/Notebooks/Preprocessing/../../Data/Processed Data/6310_eyes_open-raw.fif
# [done]
# Overwriting existing file.
# Subject 6310 processed
# ['5295']

# %% [markdown]
# ### Crop noisy spans

# %%
# MAKE SURE TO COMMENT ONCE THIS IS RUN ONCE.
# IF FORGET, CHECK FOR THE NOISY SPAN IN SIGVIEWER
need_crop = {
    '5186': False,
    '5295': False,
    # '5648': (60.5, 61.5),
    '5675': False,
    '5873': False,
    '6100': False,
    '6106': False,
    '6310': False,
}

# %%
for sub_id in sub_ids:
    if need_crop[sub_id] is not False:
        print(f'Subject {sub_id}: cropping noisy span {need_crop[sub_id]}')

        # Load whole raw data and eyes open
        raw_eo = mne.io.read_raw_fif(processed_data_path / f'{sub_id}_eyes_open-raw.fif')

        # Crop based on provided times
        raw_eo_new = preprocess.snip_span(raw_eo, need_crop[sub_id][0], need_crop[sub_id][1])
        raw_eo_new.export(data_path / f'Subject {sub_id}' / 'eyes_open.vhdr', overwrite=True)
        print(f"Subject {sub_id} noisy span cropped")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 for sub_id in sub_ids:
# ----> 2     if need_crop[sub_id] is not False:
#       3         print(f'Subject {sub_id}: cropping noisy span {need_crop[sub_id]}')
#       5         # Load whole raw data and eyes open
#
# KeyError: '5648'

# %%
for sub_id in sub_ids:
    eyes_open = mne.io.read_raw_fif(processed_data_path / f'{sub_id}_eyes_open-raw.fif')
    
    print(f'Subject {sub_id}')
    print(len(eyes_open.times)/sfreq)
# Out:
# Opening raw data file ../../Data/Processed Data/5186_eyes_open-raw.fif...
#     Range : 193081 ... 373333 =    321.802 ...   622.222 secs
# Ready.
# Subject 5186
# 300.4216666666667
# Opening raw data file ../../Data/Processed Data/5295_eyes_open-raw.fif...
#     Range : 109800 ... 289800 =    183.000 ...   483.000 secs
# Ready.
# Subject 5295
# 300.00166666666667
# Opening raw data file ../../Data/Processed Data/5648_eyes_open-raw.fif...
#     Range : 137509 ... 318421 =    229.182 ...   530.702 secs
# Ready.
# Subject 5648
# 301.52166666666665
# Opening raw data file ../../Data/Processed Data/5675_eyes_open-raw.fif...
#     Range : 8053 ... 188053 =     13.422 ...   313.422 secs
# Ready.
# Subject 5675
# 300.00166666666667
# Opening raw data file ../../Data/Processed Data/5873_eyes_open-raw.fif...
#     Range : 136393 ... 320185 =    227.322 ...   533.642 secs
# Ready.
# Subject 5873
# 306.32166666666666
# Opening raw data file ../../Data/Processed Data/6100_eyes_open-raw.fif...
#     Range : 131785 ... 313729 =    219.642 ...   522.882 secs
# Ready.
# Subject 6100
# 303.2416666666667
# Opening raw data file ../../Data/Processed Data/6106_eyes_open-raw.fif...
#     Range : 144541 ... 325789 =    240.902 ...   542.982 secs
# Ready.
# Subject 6106
# 302.08166666666665
# Opening raw data file ../../Data/Processed Data/6310_eyes_open-raw.fif...
#     Range : 186001 ... 366373 =    310.002 ...   610.622 secs
# Ready.
# Subject 6310
# 300.62166666666667

# %%
eyes_open.info['ch_names']
# Out:
# ['Fp1',
#  'Fpz',
#  'Fp2',
#  'AF7',
#  'AF3',
#  'AF4',
#  'AF8',
#  'F7',
#  'F5',
#  'F3',
#  'F1',
#  'Fz',
#  'F2',
#  'F4',
#  'F6',
#  'F8',
#  'FT7',
#  'FC5',
#  'FC3',
#  'FC1',
#  'FCz',
#  'FC2',
#  'FC4',
#  'FC6',
#  'FT8',
#  'T7',
#  'C5',
#  'C3',
#  'C1',
#  'Cz',
#  'C2',
#  'C4',
#  'C6',
#  'T8',
#  'TP7',
#  'CP5',
#  'CP3',
#  'CP1',
#  'CPz',
#  'CP2',
#  'CP4',
#  'CP6',
#  'TP8',
#  'P7',
#  'P5',
#  'P3',
#  'P1',
#  'Pz',
#  'P2',
#  'P4',
#  'P6',
#  'P8',
#  'PO7',
#  'PO3',
#  'POz',
#  'PO4',
#  'PO8',
#  'O1',
#  'Oz',
#  'O2',
#  'F9',
#  'F10',
#  'EOG']
